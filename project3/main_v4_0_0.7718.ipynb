# %% [markdown]
# # 1 初始化

# %% [markdown]
# ## 1.1 导入包

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from tqdm import tqdm
import logging

log_fmt = "[%(asctime)s] %(levelname)s in %(module)s: %(message)s"
logging.basicConfig(format=log_fmt, level=logging.INFO)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1.2 超参数定义

# %%
base_path = '/home/zengrui/datasets/190829_Kanshan_zjfx'

# %% [markdown]
# ## 1.3 函数定义

# %%
def extract_day(s):
    return s.apply(lambda x: int(x.split('-')[0][1:]))


def extract_hour(s):
    return s.apply(lambda x: int(x.split('-')[1][1:]))

# %% [markdown]
# # 2 加载、处理数据

# %% [markdown]
# ## 2.1 加载邀请回答数据

# %%
train = pd.read_csv(f'{base_path}/invite_info_0926.txt', sep='\t', header=None)
train.columns = ['qid', 'uid', 'dt', 'label']
logging.info("invite %s", train.shape)

test = pd.read_csv(f'{base_path}/invite_info_evaluate_1_0926.txt', sep='\t', header=None)
test.columns = ['qid', 'uid', 'dt']
logging.info("test %s", test.shape)

sub = test.copy()

sub_size = len(sub)

train['day'] = extract_day(train['dt'])
train['hour'] = extract_hour(train['dt'])

test['day'] = extract_day(test['dt'])
test['hour'] = extract_hour(test['dt'])

del train['dt'], test['dt']
# Out:
# [2019-12-05 21:11:21,885] INFO in <ipython-input-4-7a2c6478cb9e>: invite (9489162, 4)
# [2019-12-05 21:11:22,998] INFO in <ipython-input-4-7a2c6478cb9e>: test (1141683, 3)

# %% [markdown]
# ## 2.2 加载问题

# %%
ques = pd.read_csv(f'{base_path}/question_info_0926.txt', header=None, sep='\t')
ques.columns = ['qid', 'q_dt', 'title_t1', 'title_t2', 'desc_t1', 'desc_t2', 'topic']
del ques['title_t1'], ques['title_t2'], ques['desc_t1'], ques['desc_t2']
logging.info("ques %s", ques.shape)

ques['q_day'] = extract_day(ques['q_dt'])
ques['q_hour'] = extract_hour(ques['q_dt'])
del ques['q_dt']
# Out:
# [2019-12-05 21:11:53,656] INFO in <ipython-input-5-958902b92fc5>: ques (1829900, 3)

# %% [markdown]
# ## 2.3 加载回答

# %%
ans = pd.read_csv(f'{base_path}/answer_info_0926.txt', header=None, sep='\t')
ans.columns = ['aid', 'qid', 'uid', 'ans_dt', 'ans_t1', 'ans_t2', 'is_good', 'is_rec', 'is_dest', 'has_img',
               'has_video', 'word_count', 'reci_cheer', 'reci_uncheer', 'reci_comment', 'reci_mark', 'reci_tks',
               'reci_xxx', 'reci_no_help', 'reci_dis']
del ans['ans_t1'], ans['ans_t2']
logging.info("ans %s", ans.shape)

ans['a_day'] = extract_day(ans['ans_dt'])
ans['a_hour'] = extract_hour(ans['ans_dt'])
del ans['ans_dt']

ans = pd.merge(ans, ques, on='qid')
del ques
# Out:
# [2019-12-05 21:12:51,116] INFO in <ipython-input-6-935311f5f359>: ans (4513735, 18)

# %% [markdown]
# ## 2.4 处理时间数据

# %% [markdown]
# 回答距提问的天数。

# %%
ans['diff_qa_days'] = ans['a_day'] - ans['q_day']

# %% [markdown]
# 时间窗口划分。

# %%
train_start = 3838
train_end = 3867

val_start = 3868
val_end = 3874

label_end = 3867
label_start = label_end - 6

train_label_feature_end = label_end - 7
train_label_feature_start = train_label_feature_end - 22

train_ans_feature_end = label_end - 7
train_ans_feature_start = train_ans_feature_end - 50

val_label_feature_end = val_start - 1
val_label_feature_start = val_label_feature_end - 22

val_ans_feature_end = val_start - 1
val_ans_feature_start = val_ans_feature_end - 50

train_label_feature = train[(train['day'] >= train_label_feature_start) & (train['day'] <= train_label_feature_end)]
logging.info("train_label_feature %s", train_label_feature.shape)

val_label_feature = train[(train['day'] >= val_label_feature_start) & (train['day'] <= val_label_feature_end)]
logging.info("val_label_feature %s", val_label_feature.shape)

train_label = train[(train['day'] > train_label_feature_end)]

logging.info("train feature start %s end %s, label start %s end %s", train_label_feature['day'].min(),
             train_label_feature['day'].max(), train_label['day'].min(), train_label['day'].max())

logging.info("test feature start %s end %s, label start %s end %s", val_label_feature['day'].min(),
             val_label_feature['day'].max(), test['day'].min(), test['day'].max())
# Out:
# [2019-12-05 21:13:04,850] INFO in <ipython-input-8-5c7aac178bca>: train_label_feature (6895493, 5)
# [2019-12-05 21:13:05,455] INFO in <ipython-input-8-5c7aac178bca>: val_label_feature (7583553, 5)
# [2019-12-05 21:13:05,704] INFO in <ipython-input-8-5c7aac178bca>: train feature start 3838 end 3860, label start 3861 end 3867
# [2019-12-05 21:13:05,732] INFO in <ipython-input-8-5c7aac178bca>: test feature start 3845 end 3867, label start 3868 end 3874

# %% [markdown]
# 确定ans的时间范围。

# %%
train_ans_feature = ans[(ans['a_day'] >= train_ans_feature_start) & (ans['a_day'] <= train_ans_feature_end)]

val_ans_feature = ans[(ans['a_day'] >= val_ans_feature_start) & (ans['a_day'] <= val_ans_feature_end)]

logging.info("train ans feature %s, start %s end %s", train_ans_feature.shape, train_ans_feature['a_day'].min(),
             train_ans_feature['a_day'].max())

logging.info("val ans feature %s, start %s end %s", val_ans_feature.shape, val_ans_feature['a_day'].min(),
             val_ans_feature['a_day'].max())

fea_cols = ['is_good', 'is_rec', 'is_dest', 'has_img', 'has_video', 'word_count',
            'reci_cheer', 'reci_uncheer', 'reci_comment', 'reci_mark', 'reci_tks',
            'reci_xxx', 'reci_no_help', 'reci_dis', 'diff_qa_days']
# Out:
# [2019-12-05 21:13:08,676] INFO in <ipython-input-9-502ad99fdbbb>: train ans feature (3700178, 23), start 3810 end 3860
# [2019-12-05 21:13:08,687] INFO in <ipython-input-9-502ad99fdbbb>: val ans feature (3992334, 23), start 3817 end 3867

# %% [markdown]
# ## 2.5 特征提取

# %%
def extract_feature1(target, label_feature, ans_feature):
    # 问题特征
    t1 = label_feature.groupby('qid')['label'].agg(['mean', 'sum', 'std', 'count']).reset_index()
    t1.columns = ['qid', 'q_inv_mean', 'q_inv_sum', 'q_inv_std', 'q_inv_count']
    target = pd.merge(target, t1, on='qid', how='left')

    # 用户特征
    t1 = label_feature.groupby('uid')['label'].agg(['mean', 'sum', 'std', 'count']).reset_index()
    t1.columns = ['uid', 'u_inv_mean', 'u_inv_sum', 'u_inv_std', 'u_inv_count']
    target = pd.merge(target, t1, on='uid', how='left')
    #
    # train_size = len(train)
    # data = pd.concat((train, test), sort=True)

    # 回答部分特征

    t1 = ans_feature.groupby('qid')['aid'].count().reset_index()
    t1.columns = ['qid', 'q_ans_count']
    target = pd.merge(target, t1, on='qid', how='left')

    t1 = ans_feature.groupby('uid')['aid'].count().reset_index()
    t1.columns = ['uid', 'u_ans_count']
    target = pd.merge(target, t1, on='uid', how='left')

    for col in fea_cols:
        t1 = ans_feature.groupby('uid')[col].agg(['sum', 'max', 'mean']).reset_index()
        t1.columns = ['uid', f'u_{col}_sum', f'u_{col}_max', f'u_{col}_mean']
        target = pd.merge(target, t1, on='uid', how='left')

        t1 = ans_feature.groupby('qid')[col].agg(['sum', 'max', 'mean']).reset_index()
        t1.columns = ['qid', f'q_{col}_sum', f'q_{col}_max', f'q_{col}_mean']
        target = pd.merge(target, t1, on='qid', how='left')
        logging.info("extract %s", col)
    return target


train_label = extract_feature1(train_label, train_label_feature, train_ans_feature)
test = extract_feature1(test, val_label_feature, val_ans_feature)
# Out:
# [2019-12-05 21:13:43,123] INFO in <ipython-input-10-565ad55c944e>: extract is_good
# [2019-12-05 21:13:53,744] INFO in <ipython-input-10-565ad55c944e>: extract is_rec
# [2019-12-05 21:14:04,387] INFO in <ipython-input-10-565ad55c944e>: extract is_dest
# [2019-12-05 21:14:15,242] INFO in <ipython-input-10-565ad55c944e>: extract has_img
# [2019-12-05 21:14:26,314] INFO in <ipython-input-10-565ad55c944e>: extract has_video
# [2019-12-05 21:14:37,566] INFO in <ipython-input-10-565ad55c944e>: extract word_count
# [2019-12-05 21:14:48,907] INFO in <ipython-input-10-565ad55c944e>: extract reci_cheer
# [2019-12-05 21:15:00,437] INFO in <ipython-input-10-565ad55c944e>: extract reci_uncheer
# [2019-12-05 21:15:12,017] INFO in <ipython-input-10-565ad55c944e>: extract reci_comment
# [2019-12-05 21:15:23,737] INFO in <ipython-input-10-565ad55c944e>: extract reci_mark
# [2019-12-05 21:15:35,594] INFO in <ipython-input-10-565ad55c944e>: extract reci_tks
# [2019-12-05 21:15:47,683] INFO in <ipython-input-10-565ad55c944e>: extract reci_xxx
# [2019-12-05 21:16:00,030] INFO in <ipython-input-10-565ad55c944e>: extract reci_no_help
# [2019-12-05 21:16:12,481] INFO in <ipython-input-10-565ad55c944e>: extract reci_dis
# [2019-12-05 21:16:24,890] INFO in <ipython-input-10-565ad55c944e>: extract diff_qa_days
# [2019-12-05 21:16:56,467] INFO in <ipython-input-10-565ad55c944e>: extract is_good
# [2019-12-05 21:17:05,979] INFO in <ipython-input-10-565ad55c944e>: extract is_rec
# [2019-12-05 21:17:15,472] INFO in <ipython-input-10-565ad55c944e>: extract is_dest
# [2019-12-05 21:17:25,011] INFO in <ipython-input-10-565ad55c944e>: extract has_img
# [2019-12-05 21:17:34,672] INFO in <ipython-input-10-565ad55c944e>: extract has_video
# [2019-12-05 21:17:44,419] INFO in <ipython-input-10-565ad55c944e>: extract word_count
# [2019-12-05 21:17:54,151] INFO in <ipython-input-10-565ad55c944e>: extract reci_cheer
# [2019-12-05 21:18:03,942] INFO in <ipython-input-10-565ad55c944e>: extract reci_uncheer
# [2019-12-05 21:18:13,699] INFO in <ipython-input-10-565ad55c944e>: extract reci_comment
# [2019-12-05 21:18:23,582] INFO in <ipython-input-10-565ad55c944e>: extract reci_mark
# [2019-12-05 21:18:33,501] INFO in <ipython-input-10-565ad55c944e>: extract reci_tks
# [2019-12-05 21:18:43,544] INFO in <ipython-input-10-565ad55c944e>: extract reci_xxx
# [2019-12-05 21:18:53,578] INFO in <ipython-input-10-565ad55c944e>: extract reci_no_help
# [2019-12-05 21:19:03,594] INFO in <ipython-input-10-565ad55c944e>: extract reci_dis
# [2019-12-05 21:19:13,844] INFO in <ipython-input-10-565ad55c944e>: extract diff_qa_days

# %% [markdown]
# 特征提取结束。

# %%
logging.info("train shape %s, test shape %s", train_label.shape, test.shape)
assert len(test) == sub_size
# Out:
# [2019-12-05 21:19:13,905] INFO in <ipython-input-11-6bad7a600272>: train shape (2593669, 105), test shape (1141683, 104)

# %% [markdown]
# ## 2.6 加载用户

# %%
user = pd.read_csv(f'{base_path}/member_info_0926.txt', header=None, sep='\t')
user.columns = ['uid', 'gender', 'creat_keyword', 'level', 'hot', 'reg_type', 'reg_plat', 'freq', 'uf_b1', 'uf_b2',
                'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'score', 'follow_topic',
                'inter_topic']
del user['follow_topic'], user['inter_topic']
logging.info("user %s", user.shape)

unq = user.nunique()
logging.info("user unq %s", unq)

for x in unq[unq == 1].index:
    del user[x]
    logging.info('del unq==1 %s', x)

t = user.dtypes
cats = [x for x in t[t == 'object'].index if x not in ['follow_topic', 'inter_topic', 'uid']]
logging.info("user cat %s", cats)

for d in cats:
    lb = LabelEncoder()
    user[d] = lb.fit_transform(user[d])
    logging.info('encode %s', d)

q_lb = LabelEncoder()
q_lb.fit(list(train_label['qid'].astype(str).values) + list(test['qid'].astype(str).values))
train_label['qid_enc'] = q_lb.transform(train_label['qid'])
test['qid_enc'] = q_lb.transform(test['qid'])

u_lb = LabelEncoder()
u_lb.fit(user['uid'])
train_label['uid_enc'] = u_lb.transform(train_label['uid'])
test['uid_enc'] = u_lb.transform(test['uid'])
# Out:
# [2019-12-05 21:19:20,760] INFO in <ipython-input-12-f4f8e8f0ac9b>: user (1931654, 19)
# [2019-12-05 21:19:23,601] INFO in <ipython-input-12-f4f8e8f0ac9b>: user unq uid              1931654
# gender                 3
# creat_keyword          1
# level                  1
# hot                    1
# reg_type               1
# reg_plat               1
# freq                   5
# uf_b1                  2
# uf_b2                  2
# uf_b3                  2
# uf_b4                  2
# uf_b5                  2
# uf_c1               2561
# uf_c2                291
# uf_c3                428
# uf_c4               1556
# uf_c5                  2
# score                732
# dtype: int64
# [2019-12-05 21:19:23,655] INFO in <ipython-input-12-f4f8e8f0ac9b>: del unq==1 creat_keyword
# [2019-12-05 21:19:23,660] INFO in <ipython-input-12-f4f8e8f0ac9b>: del unq==1 level
# [2019-12-05 21:19:23,661] INFO in <ipython-input-12-f4f8e8f0ac9b>: del unq==1 hot
# [2019-12-05 21:19:23,849] INFO in <ipython-input-12-f4f8e8f0ac9b>: del unq==1 reg_type
# [2019-12-05 21:19:24,016] INFO in <ipython-input-12-f4f8e8f0ac9b>: del unq==1 reg_plat
# [2019-12-05 21:19:24,019] INFO in <ipython-input-12-f4f8e8f0ac9b>: user cat ['gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
# [2019-12-05 21:19:24,475] INFO in <ipython-input-12-f4f8e8f0ac9b>: encode gender
# [2019-12-05 21:19:24,891] INFO in <ipython-input-12-f4f8e8f0ac9b>: encode freq
# [2019-12-05 21:19:25,283] INFO in <ipython-input-12-f4f8e8f0ac9b>: encode uf_c1
# [2019-12-05 21:19:25,623] INFO in <ipython-input-12-f4f8e8f0ac9b>: encode uf_c2
# [2019-12-05 21:19:25,955] INFO in <ipython-input-12-f4f8e8f0ac9b>: encode uf_c3
# [2019-12-05 21:19:26,278] INFO in <ipython-input-12-f4f8e8f0ac9b>: encode uf_c4
# [2019-12-05 21:19:26,584] INFO in <ipython-input-12-f4f8e8f0ac9b>: encode uf_c5

# %% [markdown]
# merge user

# %%
train_label = pd.merge(train_label, user, on='uid', how='left')
test = pd.merge(test, user, on='uid', how='left')
logging.info("train shape %s, test shape %s", train_label.shape, test.shape)

# %%
data = pd.concat((train_label, test), axis=0, sort=True)
# del train_label, test

# %% [markdown]
# count编码。

# %%
count_fea = ['uid_enc', 'qid_enc', 'gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
with tqdm(total=len(count_fea)) as pbar:
    for feat in count_fea:
        col_name = '{}_count'.format(feat)
        data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
        data.loc[data[col_name] < 2, feat] = -1
        data[feat] += 1
        data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
        data[col_name] = (data[col_name] - data[col_name].min()) / (data[col_name].max() - data[col_name].min())
        pbar.update(1)

# %% [markdown]
# ## 2.7 处理数据

# %% [markdown]
# 压缩数据。

# %%
t = data.dtypes
for x in t[t == 'int64'].index:
    data[x] = data[x].astype('int32')

for x in t[t == 'float64'].index:
    data[x] = data[x].astype('float32')

data['wk'] = data['day'] % 7

feature_cols = [x for x in data.columns if x not in ('label', 'uid', 'qid', 'dt', 'day')]

# %% [markdown]
# target编码。

# %%
train_label
# Out:
#                  qid          uid  label   day  hour  q_inv_mean  q_inv_sum  \
# 0        Q2166419046   M401693808      0  3865    22         NaN        NaN
# 1         Q604029601  M2317670257      0  3862    15         NaN        NaN
# 2        Q2443223942  M3544409350      0  3867     4    0.375000       57.0
# 3         Q795459266  M2818659842      0  3861    20    0.166667        1.0
# 4         Q110462128   M848334644      1  3862     8         NaN        NaN
# ...              ...          ...    ...   ...   ...         ...        ...
# 2593664  Q3119693157  M1523603883      0  3864    20         NaN        NaN
# 2593665  Q3341450521   M479879245      0  3862    15         NaN        NaN
# 2593666  Q1458223535   M479879245      1  3867    18         NaN        NaN
# 2593667  Q3516644442  M4285896253      1  3862    12         NaN        NaN
# 2593668  Q2358485548  M4285896253      0  3864     7         NaN        NaN
#
#          q_inv_std  q_inv_count  u_inv_mean  ...  uf_b2  uf_b3  uf_b4  uf_b5  \
# 0              NaN          NaN    0.000000  ...      1      0      0      0
# 1              NaN          NaN    0.090909  ...      0      0      0      0
# 2         0.485723        152.0    0.000000  ...      0      0      0      0
# 3         0.408248          6.0    0.285714  ...      0      0      0      0
# 4              NaN          NaN    0.634146  ...      0      0      0      0
# ...            ...          ...         ...  ...    ...    ...    ...    ...
# 2593664        NaN          NaN    0.000000  ...      0      0      1      0
# 2593665        NaN          NaN    0.083333  ...      0      0      0      0
# 2593666        NaN          NaN    0.083333  ...      0      0      0      0
# 2593667        NaN          NaN    0.314286  ...      0      0      0      0
# 2593668        NaN          NaN    0.314286  ...      0      0      0      0
#
#          uf_c1  uf_c2  uf_c3  uf_c4  uf_c5  score
# 0         2113    190    261    927      1    297
# 1         1519    229      0    506      1    415
# 2          551    226    188    815      1    296
# 3         1519    229      0    506      1    380
# 4         2161     31    396   1438      1    719
# ...        ...    ...    ...    ...    ...    ...
# 2593664   1190    130    421    758      1    318
# 2593665   1190    130    315    758      1    360
# 2593666   1190    130    315    758      1    360
# 2593667    449     48      0   1311      1    586
# 2593668    449     48      0   1311      1    586
#
# [2593669 rows x 120 columns]

# %%
data
# Out:
#           day  freq  freq_count  gender  gender_count  hour  label  \
# 0        3865     5    1.000000       3      1.000000    22    0.0
# 1        3862     5    1.000000       3      1.000000    15    0.0
# 2        3867     2    0.726702       3      1.000000     4    0.0
# 3        3861     1    0.979042       2      0.487400    20    0.0
# 4        3862     5    1.000000       1      0.178696     8    1.0
# ...       ...   ...         ...     ...           ...   ...    ...
# 1141678  3869     6    0.325453       4      0.000000    20    NaN
# 1141679  3872     3    0.118357       4      0.000000    21    NaN
# 1141680  3871     2    0.726702       4      0.000000    15    NaN
# 1141681  3871     6    0.325453       4      0.000000     8    NaN
# 1141682  3873     2    0.726702       3      1.000000     9    NaN
#
#          q_ans_count  q_diff_qa_days_max  q_diff_qa_days_mean  ...  uf_c3  \
# 0                NaN                 NaN                  NaN  ...    262
# 1                NaN                 NaN                  NaN  ...      1
# 2               32.0                13.0             9.531250  ...    189
# 3                3.0               234.0           222.333328  ...      1
# 4                NaN                 NaN                  NaN  ...    397
# ...              ...                 ...                  ...  ...    ...
# 1141678          NaN                 NaN                  NaN  ...     81
# 1141679          NaN                 NaN                  NaN  ...    121
# 1141680          NaN                 NaN                  NaN  ...    313
# 1141681          NaN                 NaN                  NaN  ...      8
# 1141682          NaN                 NaN                  NaN  ...      8
#
#          uf_c3_count  uf_c4  uf_c4_count  uf_c5  uf_c5_count          uid  \
# 0           0.220357    928     0.063075      2     1.000000   M401693808
# 1           0.444174    507     0.004092      2     1.000000  M2317670257
# 2           0.403767    816     0.044312      2     1.000000  M3544409350
# 3           0.444174    507     0.004092      2     1.000000  M2818659842
# 4           0.514839   1439     0.125055      2     1.000000   M848334644
# ...              ...    ...          ...    ...          ...          ...
# 1141678     0.020067    760     0.434533      3     0.346068  M2010778235
# 1141679     0.094249    760     0.434533      3     0.346068  M3131383616
# 1141680     0.056923    760     0.434533      3     0.346068  M1872860897
# 1141681     0.442846   1375     0.031122      3     0.346068  M3574631517
# 1141682     0.442846   1132     0.029313      3     0.346068  M3168697168
#
#          uid_enc  uid_enc_count  wk
# 0        1508099       0.000000   1
# 1         657986       0.000003   5
# 2        1272354       0.000015   3
# 3         909155       0.000003   4
# 4        1856020       0.000027   5
# ...          ...            ...  ..
# 1141678   504330       0.000000   5
# 1141679  1066119       0.000003   1
# 1141680   435862       0.000000   0
# 1141681  1287652       0.000015   0
# 1141682  1084781       0.000018   2
#
# [3735352 rows x 130 columns]

# %%
logging.info("feature size %s", len(feature_cols))

X_train_all = data.iloc[:len(train_label)][feature_cols]
y_train_all = data.iloc[:len(train_label)]['label']
test = data.iloc[len(train_label):]
# del data
assert len(test) == sub_size
# Out:
# [2019-12-05 21:35:36,305] INFO in <ipython-input-29-a8e75023efc9>: feature size 126

# %% [markdown]
# # 3 训练网络

# %%
model_lgb
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=2000, n_jobs=-1, num_leaves=31, objective='binary',
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, seed=1000,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0)

# %%
logging.info("train shape %s, test shape %s", train_label.shape, test.shape)

fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for index, (train_idx, val_idx) in enumerate(fold.split(X=X_train_all, y=y_train_all)):
    break

X_train, X_val, y_train, y_val = X_train_all.iloc[train_idx][feature_cols], X_train_all.iloc[val_idx][feature_cols], \
                                 y_train_all.iloc[train_idx], \
                                 y_train_all.iloc[val_idx]
# del X_train_all

# %%
model_lgb = LGBMClassifier(n_estimators=2000, 
                           n_jobs=6, 
                           objective='binary', 
                           seed=1000, 
                           silent=True)
model_lgb.fit(X_train, y_train,
              eval_metric=['logloss', 'auc'],
              eval_set=[(X_val, y_val)],
              early_stopping_rounds=50)
# Out:
# [2019-12-05 21:35:48,701] INFO in <ipython-input-30-b5ffee06c4e2>: train shape (2593669, 120), test shape (1141683, 130)
# [1]	valid_0's auc: 0.753468	valid_0's binary_logloss: 0.427513
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's auc: 0.766018	valid_0's binary_logloss: 0.418101
# [3]	valid_0's auc: 0.772021	valid_0's binary_logloss: 0.410615
# [4]	valid_0's auc: 0.774905	valid_0's binary_logloss: 0.404363
# [5]	valid_0's auc: 0.778247	valid_0's binary_logloss: 0.398762
# [6]	valid_0's auc: 0.780496	valid_0's binary_logloss: 0.393881
# [7]	valid_0's auc: 0.782302	valid_0's binary_logloss: 0.389754
# [8]	valid_0's auc: 0.784272	valid_0's binary_logloss: 0.386325
# [9]	valid_0's auc: 0.785887	valid_0's binary_logloss: 0.383083
# [10]	valid_0's auc: 0.787088	valid_0's binary_logloss: 0.380393
# [11]	valid_0's auc: 0.788498	valid_0's binary_logloss: 0.378056
# [12]	valid_0's auc: 0.78943	valid_0's binary_logloss: 0.375943
# [13]	valid_0's auc: 0.79039	valid_0's binary_logloss: 0.374114
# [14]	valid_0's auc: 0.791517	valid_0's binary_logloss: 0.372395
# [15]	valid_0's auc: 0.792708	valid_0's binary_logloss: 0.370714
# [16]	valid_0's auc: 0.793684	valid_0's binary_logloss: 0.369282
# [17]	valid_0's auc: 0.795086	valid_0's binary_logloss: 0.367722
# [18]	valid_0's auc: 0.79611	valid_0's binary_logloss: 0.366454
# [19]	valid_0's auc: 0.797336	valid_0's binary_logloss: 0.365118
# [20]	valid_0's auc: 0.798099	valid_0's binary_logloss: 0.364104
# [21]	valid_0's auc: 0.798962	valid_0's binary_logloss: 0.363042
# [22]	valid_0's auc: 0.799865	valid_0's binary_logloss: 0.362068
# [23]	valid_0's auc: 0.800462	valid_0's binary_logloss: 0.361219
# [24]	valid_0's auc: 0.801042	valid_0's binary_logloss: 0.360449
# [25]	valid_0's auc: 0.801606	valid_0's binary_logloss: 0.359779
# [26]	valid_0's auc: 0.802279	valid_0's binary_logloss: 0.359005
# [27]	valid_0's auc: 0.80291	valid_0's binary_logloss: 0.358328
# [28]	valid_0's auc: 0.803384	valid_0's binary_logloss: 0.357794
# [29]	valid_0's auc: 0.803741	valid_0's binary_logloss: 0.35729
# [30]	valid_0's auc: 0.804321	valid_0's binary_logloss: 0.35666
# [31]	valid_0's auc: 0.804774	valid_0's binary_logloss: 0.356188
# [32]	valid_0's auc: 0.805089	valid_0's binary_logloss: 0.355785
# [33]	valid_0's auc: 0.805477	valid_0's binary_logloss: 0.355341
# [34]	valid_0's auc: 0.805722	valid_0's binary_logloss: 0.355006
# [35]	valid_0's auc: 0.806003	valid_0's binary_logloss: 0.354628
# [36]	valid_0's auc: 0.80636	valid_0's binary_logloss: 0.35426
# [37]	valid_0's auc: 0.806569	valid_0's binary_logloss: 0.353983
# [38]	valid_0's auc: 0.806907	valid_0's binary_logloss: 0.353662
# [39]	valid_0's auc: 0.807221	valid_0's binary_logloss: 0.353353
# [40]	valid_0's auc: 0.80751	valid_0's binary_logloss: 0.353046
# [41]	valid_0's auc: 0.807666	valid_0's binary_logloss: 0.352843
# [42]	valid_0's auc: 0.807896	valid_0's binary_logloss: 0.352615
# [43]	valid_0's auc: 0.808133	valid_0's binary_logloss: 0.352374
# [44]	valid_0's auc: 0.808546	valid_0's binary_logloss: 0.351981
# [45]	valid_0's auc: 0.808759	valid_0's binary_logloss: 0.351758
# [46]	valid_0's auc: 0.808945	valid_0's binary_logloss: 0.351572
# [47]	valid_0's auc: 0.809153	valid_0's binary_logloss: 0.351339
# [48]	valid_0's auc: 0.809491	valid_0's binary_logloss: 0.351051
# [49]	valid_0's auc: 0.809719	valid_0's binary_logloss: 0.350853
# [50]	valid_0's auc: 0.809882	valid_0's binary_logloss: 0.350696
# [51]	valid_0's auc: 0.810135	valid_0's binary_logloss: 0.350495
# [52]	valid_0's auc: 0.810338	valid_0's binary_logloss: 0.350294
# [53]	valid_0's auc: 0.810488	valid_0's binary_logloss: 0.350135
# [54]	valid_0's auc: 0.810854	valid_0's binary_logloss: 0.349813
# [55]	valid_0's auc: 0.811022	valid_0's binary_logloss: 0.349639
# [56]	valid_0's auc: 0.811178	valid_0's binary_logloss: 0.349493
# [57]	valid_0's auc: 0.811372	valid_0's binary_logloss: 0.349312
# [58]	valid_0's auc: 0.8115	valid_0's binary_logloss: 0.349196
# [59]	valid_0's auc: 0.811678	valid_0's binary_logloss: 0.349035
# [60]	valid_0's auc: 0.811829	valid_0's binary_logloss: 0.348914
# [61]	valid_0's auc: 0.811977	valid_0's binary_logloss: 0.348749
# [62]	valid_0's auc: 0.812166	valid_0's binary_logloss: 0.348581
# [63]	valid_0's auc: 0.812289	valid_0's binary_logloss: 0.348454
# [64]	valid_0's auc: 0.812453	valid_0's binary_logloss: 0.34833
# [65]	valid_0's auc: 0.812645	valid_0's binary_logloss: 0.34817
# [66]	valid_0's auc: 0.812854	valid_0's binary_logloss: 0.347992
# [67]	valid_0's auc: 0.812972	valid_0's binary_logloss: 0.347891
# [68]	valid_0's auc: 0.81308	valid_0's binary_logloss: 0.347798
# [69]	valid_0's auc: 0.813196	valid_0's binary_logloss: 0.347722
# [70]	valid_0's auc: 0.813302	valid_0's binary_logloss: 0.347613
# [71]	valid_0's auc: 0.813431	valid_0's binary_logloss: 0.347509
# [72]	valid_0's auc: 0.813536	valid_0's binary_logloss: 0.347415
# [73]	valid_0's auc: 0.813622	valid_0's binary_logloss: 0.347333
# [74]	valid_0's auc: 0.813703	valid_0's binary_logloss: 0.347261
# [75]	valid_0's auc: 0.813845	valid_0's binary_logloss: 0.347147
# [76]	valid_0's auc: 0.813942	valid_0's binary_logloss: 0.347082
# [77]	valid_0's auc: 0.814154	valid_0's binary_logloss: 0.346888
# [78]	valid_0's auc: 0.814254	valid_0's binary_logloss: 0.346816
# [79]	valid_0's auc: 0.814335	valid_0's binary_logloss: 0.346744
# [80]	valid_0's auc: 0.814473	valid_0's binary_logloss: 0.346614
# [81]	valid_0's auc: 0.814557	valid_0's binary_logloss: 0.346543
# [82]	valid_0's auc: 0.814635	valid_0's binary_logloss: 0.346476
# [83]	valid_0's auc: 0.8148	valid_0's binary_logloss: 0.346334
# [84]	valid_0's auc: 0.814902	valid_0's binary_logloss: 0.346246
# [85]	valid_0's auc: 0.814979	valid_0's binary_logloss: 0.346189
# [86]	valid_0's auc: 0.815111	valid_0's binary_logloss: 0.346056
# [87]	valid_0's auc: 0.815168	valid_0's binary_logloss: 0.346004
# [88]	valid_0's auc: 0.815308	valid_0's binary_logloss: 0.345888
# [89]	valid_0's auc: 0.815407	valid_0's binary_logloss: 0.345812
# [90]	valid_0's auc: 0.815475	valid_0's binary_logloss: 0.345759
# [91]	valid_0's auc: 0.815542	valid_0's binary_logloss: 0.345702
# [92]	valid_0's auc: 0.815617	valid_0's binary_logloss: 0.34565
# [93]	valid_0's auc: 0.815761	valid_0's binary_logloss: 0.345539
# [94]	valid_0's auc: 0.815901	valid_0's binary_logloss: 0.345423
# [95]	valid_0's auc: 0.815985	valid_0's binary_logloss: 0.34535
# [96]	valid_0's auc: 0.81604	valid_0's binary_logloss: 0.345303
# [97]	valid_0's auc: 0.816123	valid_0's binary_logloss: 0.345245
# [98]	valid_0's auc: 0.816203	valid_0's binary_logloss: 0.345177
# [99]	valid_0's auc: 0.816259	valid_0's binary_logloss: 0.345131
# [100]	valid_0's auc: 0.816368	valid_0's binary_logloss: 0.345034
# [101]	valid_0's auc: 0.816427	valid_0's binary_logloss: 0.344982
# [102]	valid_0's auc: 0.816483	valid_0's binary_logloss: 0.344942
# [103]	valid_0's auc: 0.81659	valid_0's binary_logloss: 0.344856
# [104]	valid_0's auc: 0.816671	valid_0's binary_logloss: 0.344786
# [105]	valid_0's auc: 0.816742	valid_0's binary_logloss: 0.344736
# [106]	valid_0's auc: 0.816882	valid_0's binary_logloss: 0.344628
# [107]	valid_0's auc: 0.816998	valid_0's binary_logloss: 0.344543
# [108]	valid_0's auc: 0.817061	valid_0's binary_logloss: 0.344491
# [109]	valid_0's auc: 0.817097	valid_0's binary_logloss: 0.344449
# [110]	valid_0's auc: 0.817216	valid_0's binary_logloss: 0.344365
# [111]	valid_0's auc: 0.817262	valid_0's binary_logloss: 0.344327
# [112]	valid_0's auc: 0.817343	valid_0's binary_logloss: 0.344265
# [113]	valid_0's auc: 0.817415	valid_0's binary_logloss: 0.344205
# [114]	valid_0's auc: 0.817481	valid_0's binary_logloss: 0.344145
# [115]	valid_0's auc: 0.817562	valid_0's binary_logloss: 0.344086
# [116]	valid_0's auc: 0.817618	valid_0's binary_logloss: 0.344045
# [117]	valid_0's auc: 0.817681	valid_0's binary_logloss: 0.344003
# [118]	valid_0's auc: 0.817736	valid_0's binary_logloss: 0.343962
# [119]	valid_0's auc: 0.81784	valid_0's binary_logloss: 0.343878
# [120]	valid_0's auc: 0.817899	valid_0's binary_logloss: 0.34383
# [121]	valid_0's auc: 0.817946	valid_0's binary_logloss: 0.343794
# [122]	valid_0's auc: 0.817966	valid_0's binary_logloss: 0.34378
# [123]	valid_0's auc: 0.818033	valid_0's binary_logloss: 0.343728
# [124]	valid_0's auc: 0.818085	valid_0's binary_logloss: 0.343688
# [125]	valid_0's auc: 0.818129	valid_0's binary_logloss: 0.34365
# [126]	valid_0's auc: 0.818164	valid_0's binary_logloss: 0.343618
# [127]	valid_0's auc: 0.818266	valid_0's binary_logloss: 0.343539
# [128]	valid_0's auc: 0.81829	valid_0's binary_logloss: 0.343524
# [129]	valid_0's auc: 0.818318	valid_0's binary_logloss: 0.343502
# [130]	valid_0's auc: 0.818357	valid_0's binary_logloss: 0.343477
# [131]	valid_0's auc: 0.818391	valid_0's binary_logloss: 0.343453
# [132]	valid_0's auc: 0.818404	valid_0's binary_logloss: 0.343445
# [133]	valid_0's auc: 0.818427	valid_0's binary_logloss: 0.343426
# [134]	valid_0's auc: 0.818468	valid_0's binary_logloss: 0.343393
# [135]	valid_0's auc: 0.818494	valid_0's binary_logloss: 0.343374
# [136]	valid_0's auc: 0.818536	valid_0's binary_logloss: 0.343338
# [137]	valid_0's auc: 0.818567	valid_0's binary_logloss: 0.343312
# [138]	valid_0's auc: 0.81861	valid_0's binary_logloss: 0.343281
# [139]	valid_0's auc: 0.81863	valid_0's binary_logloss: 0.343266
# [140]	valid_0's auc: 0.818705	valid_0's binary_logloss: 0.343178
# [141]	valid_0's auc: 0.818757	valid_0's binary_logloss: 0.343138
# [142]	valid_0's auc: 0.818802	valid_0's binary_logloss: 0.343092
# [143]	valid_0's auc: 0.818813	valid_0's binary_logloss: 0.343085
# [144]	valid_0's auc: 0.818874	valid_0's binary_logloss: 0.343043
# [145]	valid_0's auc: 0.818925	valid_0's binary_logloss: 0.343005
# [146]	valid_0's auc: 0.818939	valid_0's binary_logloss: 0.342995
# [147]	valid_0's auc: 0.819006	valid_0's binary_logloss: 0.342947
# [148]	valid_0's auc: 0.819023	valid_0's binary_logloss: 0.342936
# [149]	valid_0's auc: 0.819043	valid_0's binary_logloss: 0.342923
# [150]	valid_0's auc: 0.819063	valid_0's binary_logloss: 0.342907
# [151]	valid_0's auc: 0.819099	valid_0's binary_logloss: 0.342879
# [152]	valid_0's auc: 0.819128	valid_0's binary_logloss: 0.342858
# [153]	valid_0's auc: 0.819171	valid_0's binary_logloss: 0.342819
# [154]	valid_0's auc: 0.819218	valid_0's binary_logloss: 0.342783
# [155]	valid_0's auc: 0.819247	valid_0's binary_logloss: 0.342758
# [156]	valid_0's auc: 0.819298	valid_0's binary_logloss: 0.342716
# [157]	valid_0's auc: 0.819318	valid_0's binary_logloss: 0.342702
# [158]	valid_0's auc: 0.819437	valid_0's binary_logloss: 0.342603
# [159]	valid_0's auc: 0.819453	valid_0's binary_logloss: 0.342592
# [160]	valid_0's auc: 0.819471	valid_0's binary_logloss: 0.342576
# [161]	valid_0's auc: 0.81952	valid_0's binary_logloss: 0.34254
# [162]	valid_0's auc: 0.81952	valid_0's binary_logloss: 0.342539
# [163]	valid_0's auc: 0.819538	valid_0's binary_logloss: 0.342525
# [164]	valid_0's auc: 0.819558	valid_0's binary_logloss: 0.342513
# [165]	valid_0's auc: 0.81959	valid_0's binary_logloss: 0.342487
# [166]	valid_0's auc: 0.819647	valid_0's binary_logloss: 0.342447
# [167]	valid_0's auc: 0.819652	valid_0's binary_logloss: 0.342444
# [168]	valid_0's auc: 0.819698	valid_0's binary_logloss: 0.342404
# [169]	valid_0's auc: 0.819756	valid_0's binary_logloss: 0.342357
# [170]	valid_0's auc: 0.819827	valid_0's binary_logloss: 0.342302
# [171]	valid_0's auc: 0.819885	valid_0's binary_logloss: 0.342249
# [172]	valid_0's auc: 0.819939	valid_0's binary_logloss: 0.342199
# [173]	valid_0's auc: 0.819948	valid_0's binary_logloss: 0.342192
# [174]	valid_0's auc: 0.819959	valid_0's binary_logloss: 0.342184
# [175]	valid_0's auc: 0.819981	valid_0's binary_logloss: 0.342164
# [176]	valid_0's auc: 0.820016	valid_0's binary_logloss: 0.342141
# [177]	valid_0's auc: 0.820037	valid_0's binary_logloss: 0.342126
# [178]	valid_0's auc: 0.820059	valid_0's binary_logloss: 0.342108
# [179]	valid_0's auc: 0.820083	valid_0's binary_logloss: 0.34209
# [180]	valid_0's auc: 0.820094	valid_0's binary_logloss: 0.342078
# [181]	valid_0's auc: 0.820128	valid_0's binary_logloss: 0.342048
# [182]	valid_0's auc: 0.820149	valid_0's binary_logloss: 0.342035
# [183]	valid_0's auc: 0.82018	valid_0's binary_logloss: 0.342009
# [184]	valid_0's auc: 0.820185	valid_0's binary_logloss: 0.342006
# [185]	valid_0's auc: 0.820188	valid_0's binary_logloss: 0.342003
# [186]	valid_0's auc: 0.820241	valid_0's binary_logloss: 0.341959
# [187]	valid_0's auc: 0.820252	valid_0's binary_logloss: 0.341951
# [188]	valid_0's auc: 0.820262	valid_0's binary_logloss: 0.341944
# [189]	valid_0's auc: 0.820304	valid_0's binary_logloss: 0.341909
# [190]	valid_0's auc: 0.820319	valid_0's binary_logloss: 0.341899
# [191]	valid_0's auc: 0.82033	valid_0's binary_logloss: 0.341889
# [192]	valid_0's auc: 0.820361	valid_0's binary_logloss: 0.341866
# [193]	valid_0's auc: 0.8204	valid_0's binary_logloss: 0.341833
# [194]	valid_0's auc: 0.820412	valid_0's binary_logloss: 0.341823
# [195]	valid_0's auc: 0.820429	valid_0's binary_logloss: 0.341811
# [196]	valid_0's auc: 0.820438	valid_0's binary_logloss: 0.341805
# [197]	valid_0's auc: 0.820441	valid_0's binary_logloss: 0.341803
# [198]	valid_0's auc: 0.82048	valid_0's binary_logloss: 0.341777
# [199]	valid_0's auc: 0.820528	valid_0's binary_logloss: 0.341742
# [200]	valid_0's auc: 0.820593	valid_0's binary_logloss: 0.341698
# [201]	valid_0's auc: 0.820604	valid_0's binary_logloss: 0.341693
# [202]	valid_0's auc: 0.820611	valid_0's binary_logloss: 0.341688
# [203]	valid_0's auc: 0.820652	valid_0's binary_logloss: 0.341656
# [204]	valid_0's auc: 0.820662	valid_0's binary_logloss: 0.341649
# [205]	valid_0's auc: 0.820678	valid_0's binary_logloss: 0.341638
# [206]	valid_0's auc: 0.820701	valid_0's binary_logloss: 0.341618
# [207]	valid_0's auc: 0.820723	valid_0's binary_logloss: 0.341599
# [208]	valid_0's auc: 0.820756	valid_0's binary_logloss: 0.341573
# [209]	valid_0's auc: 0.820779	valid_0's binary_logloss: 0.341554
# [210]	valid_0's auc: 0.820781	valid_0's binary_logloss: 0.34155
# [211]	valid_0's auc: 0.820793	valid_0's binary_logloss: 0.341544
# [212]	valid_0's auc: 0.820802	valid_0's binary_logloss: 0.341537
# [213]	valid_0's auc: 0.820807	valid_0's binary_logloss: 0.341533
# [214]	valid_0's auc: 0.820814	valid_0's binary_logloss: 0.34153
# [215]	valid_0's auc: 0.820834	valid_0's binary_logloss: 0.341516
# [216]	valid_0's auc: 0.820842	valid_0's binary_logloss: 0.341506
# [217]	valid_0's auc: 0.820845	valid_0's binary_logloss: 0.341503
# [218]	valid_0's auc: 0.82087	valid_0's binary_logloss: 0.341486
# [219]	valid_0's auc: 0.820878	valid_0's binary_logloss: 0.341481
# [220]	valid_0's auc: 0.820887	valid_0's binary_logloss: 0.341475
# [221]	valid_0's auc: 0.820886	valid_0's binary_logloss: 0.341474
# [222]	valid_0's auc: 0.820929	valid_0's binary_logloss: 0.341445
# [223]	valid_0's auc: 0.820934	valid_0's binary_logloss: 0.341442
# [224]	valid_0's auc: 0.820951	valid_0's binary_logloss: 0.341427
# [225]	valid_0's auc: 0.821	valid_0's binary_logloss: 0.341386
# [226]	valid_0's auc: 0.82101	valid_0's binary_logloss: 0.341377
# [227]	valid_0's auc: 0.821029	valid_0's binary_logloss: 0.341364
# [228]	valid_0's auc: 0.821054	valid_0's binary_logloss: 0.341342
# [229]	valid_0's auc: 0.821065	valid_0's binary_logloss: 0.341334
# [230]	valid_0's auc: 0.821073	valid_0's binary_logloss: 0.34133
# [231]	valid_0's auc: 0.821086	valid_0's binary_logloss: 0.341322
# [232]	valid_0's auc: 0.821096	valid_0's binary_logloss: 0.341315
# [233]	valid_0's auc: 0.821112	valid_0's binary_logloss: 0.341303
# [234]	valid_0's auc: 0.821129	valid_0's binary_logloss: 0.341292
# [235]	valid_0's auc: 0.821141	valid_0's binary_logloss: 0.341284
# [236]	valid_0's auc: 0.82115	valid_0's binary_logloss: 0.341278
# [237]	valid_0's auc: 0.821182	valid_0's binary_logloss: 0.34125
# [238]	valid_0's auc: 0.821218	valid_0's binary_logloss: 0.341224
# [239]	valid_0's auc: 0.821258	valid_0's binary_logloss: 0.341194
# [240]	valid_0's auc: 0.821261	valid_0's binary_logloss: 0.34119
# [241]	valid_0's auc: 0.821287	valid_0's binary_logloss: 0.341165
# [242]	valid_0's auc: 0.821289	valid_0's binary_logloss: 0.341163
# [243]	valid_0's auc: 0.821302	valid_0's binary_logloss: 0.341156
# [244]	valid_0's auc: 0.821304	valid_0's binary_logloss: 0.341155
# [245]	valid_0's auc: 0.821324	valid_0's binary_logloss: 0.341139
# [246]	valid_0's auc: 0.821354	valid_0's binary_logloss: 0.341116
# [247]	valid_0's auc: 0.821357	valid_0's binary_logloss: 0.341113
# [248]	valid_0's auc: 0.821359	valid_0's binary_logloss: 0.341111
# [249]	valid_0's auc: 0.821369	valid_0's binary_logloss: 0.341105
# [250]	valid_0's auc: 0.821374	valid_0's binary_logloss: 0.341097
# [251]	valid_0's auc: 0.821376	valid_0's binary_logloss: 0.341096
# [252]	valid_0's auc: 0.821394	valid_0's binary_logloss: 0.341082
# [253]	valid_0's auc: 0.821405	valid_0's binary_logloss: 0.341071
# [254]	valid_0's auc: 0.821422	valid_0's binary_logloss: 0.34106
# [255]	valid_0's auc: 0.821431	valid_0's binary_logloss: 0.341053
# [256]	valid_0's auc: 0.821451	valid_0's binary_logloss: 0.341031
# [257]	valid_0's auc: 0.821468	valid_0's binary_logloss: 0.341017
# [258]	valid_0's auc: 0.821497	valid_0's binary_logloss: 0.340995
# [259]	valid_0's auc: 0.821499	valid_0's binary_logloss: 0.340993
# [260]	valid_0's auc: 0.82152	valid_0's binary_logloss: 0.340975
# [261]	valid_0's auc: 0.821545	valid_0's binary_logloss: 0.340959
# [262]	valid_0's auc: 0.821546	valid_0's binary_logloss: 0.340958
# [263]	valid_0's auc: 0.821567	valid_0's binary_logloss: 0.34094
# [264]	valid_0's auc: 0.821594	valid_0's binary_logloss: 0.34092
# [265]	valid_0's auc: 0.821634	valid_0's binary_logloss: 0.340894
# [266]	valid_0's auc: 0.821664	valid_0's binary_logloss: 0.340872
# [267]	valid_0's auc: 0.821701	valid_0's binary_logloss: 0.34084
# [268]	valid_0's auc: 0.821728	valid_0's binary_logloss: 0.340817
# [269]	valid_0's auc: 0.821744	valid_0's binary_logloss: 0.340804
# [270]	valid_0's auc: 0.821756	valid_0's binary_logloss: 0.340795
# [271]	valid_0's auc: 0.821762	valid_0's binary_logloss: 0.34079
# [272]	valid_0's auc: 0.821771	valid_0's binary_logloss: 0.340784
# [273]	valid_0's auc: 0.821768	valid_0's binary_logloss: 0.340785
# [274]	valid_0's auc: 0.821769	valid_0's binary_logloss: 0.340784
# [275]	valid_0's auc: 0.821814	valid_0's binary_logloss: 0.340751
# [276]	valid_0's auc: 0.821856	valid_0's binary_logloss: 0.340716
# [277]	valid_0's auc: 0.821892	valid_0's binary_logloss: 0.340689
# [278]	valid_0's auc: 0.821919	valid_0's binary_logloss: 0.34067
# [279]	valid_0's auc: 0.821931	valid_0's binary_logloss: 0.340663
# [280]	valid_0's auc: 0.821975	valid_0's binary_logloss: 0.340628
# [281]	valid_0's auc: 0.821989	valid_0's binary_logloss: 0.340614
# [282]	valid_0's auc: 0.821994	valid_0's binary_logloss: 0.340611
# [283]	valid_0's auc: 0.822037	valid_0's binary_logloss: 0.340581
# [284]	valid_0's auc: 0.822042	valid_0's binary_logloss: 0.340576
# [285]	valid_0's auc: 0.822055	valid_0's binary_logloss: 0.34056
# [286]	valid_0's auc: 0.822054	valid_0's binary_logloss: 0.340561
# [287]	valid_0's auc: 0.822067	valid_0's binary_logloss: 0.340553
# [288]	valid_0's auc: 0.822075	valid_0's binary_logloss: 0.340547
# [289]	valid_0's auc: 0.822096	valid_0's binary_logloss: 0.340534
# [290]	valid_0's auc: 0.822104	valid_0's binary_logloss: 0.340529
# [291]	valid_0's auc: 0.822108	valid_0's binary_logloss: 0.340525
# [292]	valid_0's auc: 0.822106	valid_0's binary_logloss: 0.340525
# [293]	valid_0's auc: 0.82213	valid_0's binary_logloss: 0.340506
# [294]	valid_0's auc: 0.82217	valid_0's binary_logloss: 0.340476
# [295]	valid_0's auc: 0.822192	valid_0's binary_logloss: 0.340453
# [296]	valid_0's auc: 0.822195	valid_0's binary_logloss: 0.340451
# [297]	valid_0's auc: 0.822204	valid_0's binary_logloss: 0.340439
# [298]	valid_0's auc: 0.822199	valid_0's binary_logloss: 0.340443
# [299]	valid_0's auc: 0.822222	valid_0's binary_logloss: 0.340425
# [300]	valid_0's auc: 0.822233	valid_0's binary_logloss: 0.340417
# [301]	valid_0's auc: 0.822252	valid_0's binary_logloss: 0.340403
# [302]	valid_0's auc: 0.822254	valid_0's binary_logloss: 0.340402
# [303]	valid_0's auc: 0.822257	valid_0's binary_logloss: 0.3404
# [304]	valid_0's auc: 0.822264	valid_0's binary_logloss: 0.340395
# [305]	valid_0's auc: 0.822267	valid_0's binary_logloss: 0.340393
# [306]	valid_0's auc: 0.822281	valid_0's binary_logloss: 0.340384
# [307]	valid_0's auc: 0.8223	valid_0's binary_logloss: 0.340368
# [308]	valid_0's auc: 0.822312	valid_0's binary_logloss: 0.340357
# [309]	valid_0's auc: 0.822321	valid_0's binary_logloss: 0.34035
# [310]	valid_0's auc: 0.822323	valid_0's binary_logloss: 0.340348
# [311]	valid_0's auc: 0.822334	valid_0's binary_logloss: 0.340341
# [312]	valid_0's auc: 0.822346	valid_0's binary_logloss: 0.34033
# [313]	valid_0's auc: 0.822353	valid_0's binary_logloss: 0.340324
# [314]	valid_0's auc: 0.822366	valid_0's binary_logloss: 0.340315
# [315]	valid_0's auc: 0.822377	valid_0's binary_logloss: 0.340308
# [316]	valid_0's auc: 0.822389	valid_0's binary_logloss: 0.340296
# [317]	valid_0's auc: 0.822418	valid_0's binary_logloss: 0.340271
# [318]	valid_0's auc: 0.822425	valid_0's binary_logloss: 0.340266
# [319]	valid_0's auc: 0.822436	valid_0's binary_logloss: 0.340258
# [320]	valid_0's auc: 0.822446	valid_0's binary_logloss: 0.340251
# [321]	valid_0's auc: 0.822454	valid_0's binary_logloss: 0.340246
# [322]	valid_0's auc: 0.822466	valid_0's binary_logloss: 0.340237
# [323]	valid_0's auc: 0.822475	valid_0's binary_logloss: 0.340231
# [324]	valid_0's auc: 0.822494	valid_0's binary_logloss: 0.340218
# [325]	valid_0's auc: 0.822524	valid_0's binary_logloss: 0.3402
# [326]	valid_0's auc: 0.822548	valid_0's binary_logloss: 0.34018
# [327]	valid_0's auc: 0.822555	valid_0's binary_logloss: 0.340172
# [328]	valid_0's auc: 0.822556	valid_0's binary_logloss: 0.340172
# [329]	valid_0's auc: 0.822583	valid_0's binary_logloss: 0.340154
# [330]	valid_0's auc: 0.8226	valid_0's binary_logloss: 0.340137
# [331]	valid_0's auc: 0.822611	valid_0's binary_logloss: 0.340131
# [332]	valid_0's auc: 0.822618	valid_0's binary_logloss: 0.340125
# [333]	valid_0's auc: 0.822618	valid_0's binary_logloss: 0.340125
# [334]	valid_0's auc: 0.822652	valid_0's binary_logloss: 0.340104
# [335]	valid_0's auc: 0.822654	valid_0's binary_logloss: 0.340101
# [336]	valid_0's auc: 0.822655	valid_0's binary_logloss: 0.3401
# [337]	valid_0's auc: 0.822659	valid_0's binary_logloss: 0.340097
# [338]	valid_0's auc: 0.822675	valid_0's binary_logloss: 0.34008
# [339]	valid_0's auc: 0.822688	valid_0's binary_logloss: 0.340071
# [340]	valid_0's auc: 0.82269	valid_0's binary_logloss: 0.34007
# [341]	valid_0's auc: 0.822696	valid_0's binary_logloss: 0.340067
# [342]	valid_0's auc: 0.822705	valid_0's binary_logloss: 0.34006
# [343]	valid_0's auc: 0.822723	valid_0's binary_logloss: 0.340045
# [344]	valid_0's auc: 0.822744	valid_0's binary_logloss: 0.340028
# [345]	valid_0's auc: 0.822753	valid_0's binary_logloss: 0.340019
# [346]	valid_0's auc: 0.82276	valid_0's binary_logloss: 0.340012
# [347]	valid_0's auc: 0.822777	valid_0's binary_logloss: 0.34
# [348]	valid_0's auc: 0.822797	valid_0's binary_logloss: 0.339982
# [349]	valid_0's auc: 0.822801	valid_0's binary_logloss: 0.339979
# [350]	valid_0's auc: 0.822803	valid_0's binary_logloss: 0.339977
# [351]	valid_0's auc: 0.822806	valid_0's binary_logloss: 0.339974
# [352]	valid_0's auc: 0.822811	valid_0's binary_logloss: 0.339972
# [353]	valid_0's auc: 0.822825	valid_0's binary_logloss: 0.339963
# [354]	valid_0's auc: 0.822824	valid_0's binary_logloss: 0.339963
# [355]	valid_0's auc: 0.822835	valid_0's binary_logloss: 0.339953
# [356]	valid_0's auc: 0.822847	valid_0's binary_logloss: 0.339946
# [357]	valid_0's auc: 0.822852	valid_0's binary_logloss: 0.339943
# [358]	valid_0's auc: 0.822861	valid_0's binary_logloss: 0.339935
# [359]	valid_0's auc: 0.822862	valid_0's binary_logloss: 0.339934
# [360]	valid_0's auc: 0.822875	valid_0's binary_logloss: 0.339924
# [361]	valid_0's auc: 0.822884	valid_0's binary_logloss: 0.339917
# [362]	valid_0's auc: 0.822887	valid_0's binary_logloss: 0.339914
# [363]	valid_0's auc: 0.822886	valid_0's binary_logloss: 0.339913
# [364]	valid_0's auc: 0.822887	valid_0's binary_logloss: 0.339913
# [365]	valid_0's auc: 0.822905	valid_0's binary_logloss: 0.339901
# [366]	valid_0's auc: 0.822912	valid_0's binary_logloss: 0.339896
# [367]	valid_0's auc: 0.822912	valid_0's binary_logloss: 0.339897
# [368]	valid_0's auc: 0.822913	valid_0's binary_logloss: 0.339895
# [369]	valid_0's auc: 0.822913	valid_0's binary_logloss: 0.339893
# [370]	valid_0's auc: 0.822921	valid_0's binary_logloss: 0.339886
# [371]	valid_0's auc: 0.82293	valid_0's binary_logloss: 0.339879
# [372]	valid_0's auc: 0.822937	valid_0's binary_logloss: 0.339875
# [373]	valid_0's auc: 0.822947	valid_0's binary_logloss: 0.339869
# [374]	valid_0's auc: 0.822957	valid_0's binary_logloss: 0.339861
# [375]	valid_0's auc: 0.822956	valid_0's binary_logloss: 0.339862
# [376]	valid_0's auc: 0.822958	valid_0's binary_logloss: 0.339861
# [377]	valid_0's auc: 0.822973	valid_0's binary_logloss: 0.339852
# [378]	valid_0's auc: 0.822973	valid_0's binary_logloss: 0.339852
# [379]	valid_0's auc: 0.822976	valid_0's binary_logloss: 0.339849
# [380]	valid_0's auc: 0.82299	valid_0's binary_logloss: 0.339839
# [381]	valid_0's auc: 0.823005	valid_0's binary_logloss: 0.339826
# [382]	valid_0's auc: 0.823007	valid_0's binary_logloss: 0.339824
# [383]	valid_0's auc: 0.82302	valid_0's binary_logloss: 0.339814
# [384]	valid_0's auc: 0.82302	valid_0's binary_logloss: 0.339812
# [385]	valid_0's auc: 0.82302	valid_0's binary_logloss: 0.339812
# [386]	valid_0's auc: 0.823025	valid_0's binary_logloss: 0.339807
# [387]	valid_0's auc: 0.823041	valid_0's binary_logloss: 0.339792
# [388]	valid_0's auc: 0.823046	valid_0's binary_logloss: 0.339787
# [389]	valid_0's auc: 0.823054	valid_0's binary_logloss: 0.339781
# [390]	valid_0's auc: 0.823053	valid_0's binary_logloss: 0.339781
# [391]	valid_0's auc: 0.823054	valid_0's binary_logloss: 0.339781
# [392]	valid_0's auc: 0.823052	valid_0's binary_logloss: 0.339783
# [393]	valid_0's auc: 0.823051	valid_0's binary_logloss: 0.339782
# [394]	valid_0's auc: 0.823055	valid_0's binary_logloss: 0.339778
# [395]	valid_0's auc: 0.823089	valid_0's binary_logloss: 0.33975
# [396]	valid_0's auc: 0.823119	valid_0's binary_logloss: 0.339726
# [397]	valid_0's auc: 0.823149	valid_0's binary_logloss: 0.339702
# [398]	valid_0's auc: 0.823157	valid_0's binary_logloss: 0.339697
# [399]	valid_0's auc: 0.823155	valid_0's binary_logloss: 0.339696
# [400]	valid_0's auc: 0.823187	valid_0's binary_logloss: 0.339673
# [401]	valid_0's auc: 0.823213	valid_0's binary_logloss: 0.339653
# [402]	valid_0's auc: 0.823223	valid_0's binary_logloss: 0.339647
# [403]	valid_0's auc: 0.823236	valid_0's binary_logloss: 0.339638
# [404]	valid_0's auc: 0.823276	valid_0's binary_logloss: 0.339605
# [405]	valid_0's auc: 0.823285	valid_0's binary_logloss: 0.339599
# [406]	valid_0's auc: 0.823317	valid_0's binary_logloss: 0.339575
# [407]	valid_0's auc: 0.823324	valid_0's binary_logloss: 0.339571
# [408]	valid_0's auc: 0.823328	valid_0's binary_logloss: 0.339567
# [409]	valid_0's auc: 0.823328	valid_0's binary_logloss: 0.339567
# [410]	valid_0's auc: 0.82334	valid_0's binary_logloss: 0.33956
# [411]	valid_0's auc: 0.823359	valid_0's binary_logloss: 0.339546
# [412]	valid_0's auc: 0.823363	valid_0's binary_logloss: 0.33954
# [413]	valid_0's auc: 0.823368	valid_0's binary_logloss: 0.339535
# [414]	valid_0's auc: 0.823372	valid_0's binary_logloss: 0.339531
# [415]	valid_0's auc: 0.823374	valid_0's binary_logloss: 0.33953
# [416]	valid_0's auc: 0.823407	valid_0's binary_logloss: 0.339489
# [417]	valid_0's auc: 0.823426	valid_0's binary_logloss: 0.339477
# [418]	valid_0's auc: 0.823445	valid_0's binary_logloss: 0.339463
# [419]	valid_0's auc: 0.823444	valid_0's binary_logloss: 0.339463
# [420]	valid_0's auc: 0.823449	valid_0's binary_logloss: 0.33946
# [421]	valid_0's auc: 0.823485	valid_0's binary_logloss: 0.339433
# [422]	valid_0's auc: 0.823488	valid_0's binary_logloss: 0.33943
# [423]	valid_0's auc: 0.823487	valid_0's binary_logloss: 0.339431
# [424]	valid_0's auc: 0.8235	valid_0's binary_logloss: 0.339421
# [425]	valid_0's auc: 0.823509	valid_0's binary_logloss: 0.339413
# [426]	valid_0's auc: 0.823518	valid_0's binary_logloss: 0.339407
# [427]	valid_0's auc: 0.823524	valid_0's binary_logloss: 0.339402
# [428]	valid_0's auc: 0.823535	valid_0's binary_logloss: 0.339393
# [429]	valid_0's auc: 0.82354	valid_0's binary_logloss: 0.339389
# [430]	valid_0's auc: 0.823542	valid_0's binary_logloss: 0.339387
# [431]	valid_0's auc: 0.823544	valid_0's binary_logloss: 0.339386
# [432]	valid_0's auc: 0.823547	valid_0's binary_logloss: 0.339385
# [433]	valid_0's auc: 0.823542	valid_0's binary_logloss: 0.339387
# [434]	valid_0's auc: 0.823539	valid_0's binary_logloss: 0.339389
# [435]	valid_0's auc: 0.823538	valid_0's binary_logloss: 0.339388
# [436]	valid_0's auc: 0.823559	valid_0's binary_logloss: 0.339375
# [437]	valid_0's auc: 0.823562	valid_0's binary_logloss: 0.339372
# [438]	valid_0's auc: 0.823572	valid_0's binary_logloss: 0.339367
# [439]	valid_0's auc: 0.823603	valid_0's binary_logloss: 0.339334
# [440]	valid_0's auc: 0.823638	valid_0's binary_logloss: 0.339306
# [441]	valid_0's auc: 0.823684	valid_0's binary_logloss: 0.339275
# [442]	valid_0's auc: 0.823719	valid_0's binary_logloss: 0.33925
# [443]	valid_0's auc: 0.823725	valid_0's binary_logloss: 0.339245
# [444]	valid_0's auc: 0.823735	valid_0's binary_logloss: 0.339236
# [445]	valid_0's auc: 0.823734	valid_0's binary_logloss: 0.339237
# [446]	valid_0's auc: 0.823744	valid_0's binary_logloss: 0.339225
# [447]	valid_0's auc: 0.823762	valid_0's binary_logloss: 0.339213
# [448]	valid_0's auc: 0.823766	valid_0's binary_logloss: 0.339211
# [449]	valid_0's auc: 0.823774	valid_0's binary_logloss: 0.339205
# [450]	valid_0's auc: 0.82378	valid_0's binary_logloss: 0.339201
# [451]	valid_0's auc: 0.823779	valid_0's binary_logloss: 0.339201
# [452]	valid_0's auc: 0.823804	valid_0's binary_logloss: 0.339186
# [453]	valid_0's auc: 0.823804	valid_0's binary_logloss: 0.339185
# [454]	valid_0's auc: 0.823809	valid_0's binary_logloss: 0.339181
# [455]	valid_0's auc: 0.823812	valid_0's binary_logloss: 0.339179
# [456]	valid_0's auc: 0.823811	valid_0's binary_logloss: 0.33918
# [457]	valid_0's auc: 0.82382	valid_0's binary_logloss: 0.339173
# [458]	valid_0's auc: 0.823825	valid_0's binary_logloss: 0.339167
# [459]	valid_0's auc: 0.823845	valid_0's binary_logloss: 0.339153
# [460]	valid_0's auc: 0.823846	valid_0's binary_logloss: 0.339153
# [461]	valid_0's auc: 0.823849	valid_0's binary_logloss: 0.339152
# [462]	valid_0's auc: 0.823851	valid_0's binary_logloss: 0.339151
# [463]	valid_0's auc: 0.823858	valid_0's binary_logloss: 0.339147
# [464]	valid_0's auc: 0.823862	valid_0's binary_logloss: 0.339143
# [465]	valid_0's auc: 0.823863	valid_0's binary_logloss: 0.339142
# [466]	valid_0's auc: 0.823873	valid_0's binary_logloss: 0.339137
# [467]	valid_0's auc: 0.823894	valid_0's binary_logloss: 0.339119
# [468]	valid_0's auc: 0.8239	valid_0's binary_logloss: 0.339115
# [469]	valid_0's auc: 0.823904	valid_0's binary_logloss: 0.339111
# [470]	valid_0's auc: 0.82391	valid_0's binary_logloss: 0.339107
# [471]	valid_0's auc: 0.823931	valid_0's binary_logloss: 0.33909
# [472]	valid_0's auc: 0.823936	valid_0's binary_logloss: 0.339087
# [473]	valid_0's auc: 0.823944	valid_0's binary_logloss: 0.33908
# [474]	valid_0's auc: 0.823949	valid_0's binary_logloss: 0.339074
# [475]	valid_0's auc: 0.823964	valid_0's binary_logloss: 0.339065
# [476]	valid_0's auc: 0.823972	valid_0's binary_logloss: 0.33906
# [477]	valid_0's auc: 0.82398	valid_0's binary_logloss: 0.339054
# [478]	valid_0's auc: 0.823976	valid_0's binary_logloss: 0.339056
# [479]	valid_0's auc: 0.82399	valid_0's binary_logloss: 0.339046
# [480]	valid_0's auc: 0.824005	valid_0's binary_logloss: 0.339035
# [481]	valid_0's auc: 0.824007	valid_0's binary_logloss: 0.339034
# [482]	valid_0's auc: 0.824015	valid_0's binary_logloss: 0.339027
# [483]	valid_0's auc: 0.824019	valid_0's binary_logloss: 0.339023
# [484]	valid_0's auc: 0.824033	valid_0's binary_logloss: 0.339012
# [485]	valid_0's auc: 0.824044	valid_0's binary_logloss: 0.339005
# [486]	valid_0's auc: 0.824051	valid_0's binary_logloss: 0.339001
# [487]	valid_0's auc: 0.824054	valid_0's binary_logloss: 0.338998
# [488]	valid_0's auc: 0.824086	valid_0's binary_logloss: 0.338973
# [489]	valid_0's auc: 0.824087	valid_0's binary_logloss: 0.338971
# [490]	valid_0's auc: 0.824088	valid_0's binary_logloss: 0.33897
# [491]	valid_0's auc: 0.824085	valid_0's binary_logloss: 0.338973
# [492]	valid_0's auc: 0.824083	valid_0's binary_logloss: 0.338973
# [493]	valid_0's auc: 0.824104	valid_0's binary_logloss: 0.338952
# [494]	valid_0's auc: 0.82411	valid_0's binary_logloss: 0.338948
# [495]	valid_0's auc: 0.824119	valid_0's binary_logloss: 0.338942
# [496]	valid_0's auc: 0.824123	valid_0's binary_logloss: 0.338939
# [497]	valid_0's auc: 0.824132	valid_0's binary_logloss: 0.338932
# [498]	valid_0's auc: 0.82413	valid_0's binary_logloss: 0.338932
# [499]	valid_0's auc: 0.824138	valid_0's binary_logloss: 0.338926
# [500]	valid_0's auc: 0.824138	valid_0's binary_logloss: 0.338926
# [501]	valid_0's auc: 0.824174	valid_0's binary_logloss: 0.3389
# [502]	valid_0's auc: 0.824191	valid_0's binary_logloss: 0.338884
# [503]	valid_0's auc: 0.824207	valid_0's binary_logloss: 0.338875
# [504]	valid_0's auc: 0.824218	valid_0's binary_logloss: 0.338869
# [505]	valid_0's auc: 0.82422	valid_0's binary_logloss: 0.338867
# [506]	valid_0's auc: 0.824223	valid_0's binary_logloss: 0.338865
# [507]	valid_0's auc: 0.824227	valid_0's binary_logloss: 0.338862
# [508]	valid_0's auc: 0.824227	valid_0's binary_logloss: 0.33886
# [509]	valid_0's auc: 0.824229	valid_0's binary_logloss: 0.338859
# [510]	valid_0's auc: 0.824237	valid_0's binary_logloss: 0.338854
# [511]	valid_0's auc: 0.824233	valid_0's binary_logloss: 0.338856
# [512]	valid_0's auc: 0.824252	valid_0's binary_logloss: 0.338842
# [513]	valid_0's auc: 0.824258	valid_0's binary_logloss: 0.338836
# [514]	valid_0's auc: 0.824262	valid_0's binary_logloss: 0.338832
# [515]	valid_0's auc: 0.824276	valid_0's binary_logloss: 0.338822
# [516]	valid_0's auc: 0.82428	valid_0's binary_logloss: 0.338818
# [517]	valid_0's auc: 0.824292	valid_0's binary_logloss: 0.338808
# [518]	valid_0's auc: 0.824299	valid_0's binary_logloss: 0.338803
# [519]	valid_0's auc: 0.82431	valid_0's binary_logloss: 0.338789
# [520]	valid_0's auc: 0.824324	valid_0's binary_logloss: 0.338777
# [521]	valid_0's auc: 0.824332	valid_0's binary_logloss: 0.33877
# [522]	valid_0's auc: 0.824334	valid_0's binary_logloss: 0.338769
# [523]	valid_0's auc: 0.824336	valid_0's binary_logloss: 0.338766
# [524]	valid_0's auc: 0.824332	valid_0's binary_logloss: 0.33877
# [525]	valid_0's auc: 0.824338	valid_0's binary_logloss: 0.338764
# [526]	valid_0's auc: 0.82435	valid_0's binary_logloss: 0.338756
# [527]	valid_0's auc: 0.824356	valid_0's binary_logloss: 0.338752
# [528]	valid_0's auc: 0.824362	valid_0's binary_logloss: 0.338746
# [529]	valid_0's auc: 0.824374	valid_0's binary_logloss: 0.338738
# [530]	valid_0's auc: 0.824376	valid_0's binary_logloss: 0.338736
# [531]	valid_0's auc: 0.824389	valid_0's binary_logloss: 0.33872
# [532]	valid_0's auc: 0.824413	valid_0's binary_logloss: 0.338703
# [533]	valid_0's auc: 0.824426	valid_0's binary_logloss: 0.338693
# [534]	valid_0's auc: 0.82443	valid_0's binary_logloss: 0.338689
# [535]	valid_0's auc: 0.824432	valid_0's binary_logloss: 0.338687
# [536]	valid_0's auc: 0.82444	valid_0's binary_logloss: 0.338679
# [537]	valid_0's auc: 0.824437	valid_0's binary_logloss: 0.33868
# [538]	valid_0's auc: 0.824451	valid_0's binary_logloss: 0.338668
# [539]	valid_0's auc: 0.824464	valid_0's binary_logloss: 0.338658
# [540]	valid_0's auc: 0.824494	valid_0's binary_logloss: 0.338637
# [541]	valid_0's auc: 0.824496	valid_0's binary_logloss: 0.338636
# [542]	valid_0's auc: 0.824509	valid_0's binary_logloss: 0.338624
# [543]	valid_0's auc: 0.824529	valid_0's binary_logloss: 0.338611
# [544]	valid_0's auc: 0.824529	valid_0's binary_logloss: 0.338611
# [545]	valid_0's auc: 0.824526	valid_0's binary_logloss: 0.338613
# [546]	valid_0's auc: 0.824529	valid_0's binary_logloss: 0.33861
# [547]	valid_0's auc: 0.824527	valid_0's binary_logloss: 0.338611
# [548]	valid_0's auc: 0.82453	valid_0's binary_logloss: 0.338609
# [549]	valid_0's auc: 0.82453	valid_0's binary_logloss: 0.338609
# [550]	valid_0's auc: 0.824529	valid_0's binary_logloss: 0.338609
# [551]	valid_0's auc: 0.824545	valid_0's binary_logloss: 0.338599
# [552]	valid_0's auc: 0.824557	valid_0's binary_logloss: 0.33859
# [553]	valid_0's auc: 0.824564	valid_0's binary_logloss: 0.338584
# [554]	valid_0's auc: 0.824568	valid_0's binary_logloss: 0.338582
# [555]	valid_0's auc: 0.824573	valid_0's binary_logloss: 0.338577
# [556]	valid_0's auc: 0.824583	valid_0's binary_logloss: 0.33857
# [557]	valid_0's auc: 0.824596	valid_0's binary_logloss: 0.33856
# [558]	valid_0's auc: 0.824605	valid_0's binary_logloss: 0.338553
# [559]	valid_0's auc: 0.824612	valid_0's binary_logloss: 0.338547
# [560]	valid_0's auc: 0.824611	valid_0's binary_logloss: 0.338547
# [561]	valid_0's auc: 0.824622	valid_0's binary_logloss: 0.338535
# [562]	valid_0's auc: 0.824629	valid_0's binary_logloss: 0.33853
# [563]	valid_0's auc: 0.824634	valid_0's binary_logloss: 0.338527
# [564]	valid_0's auc: 0.824637	valid_0's binary_logloss: 0.338525
# [565]	valid_0's auc: 0.824636	valid_0's binary_logloss: 0.338526
# [566]	valid_0's auc: 0.824638	valid_0's binary_logloss: 0.338525
# [567]	valid_0's auc: 0.824648	valid_0's binary_logloss: 0.338516
# [568]	valid_0's auc: 0.824655	valid_0's binary_logloss: 0.33851
# [569]	valid_0's auc: 0.824675	valid_0's binary_logloss: 0.338497
# [570]	valid_0's auc: 0.824688	valid_0's binary_logloss: 0.338486
# [571]	valid_0's auc: 0.824693	valid_0's binary_logloss: 0.338483
# [572]	valid_0's auc: 0.824699	valid_0's binary_logloss: 0.338481
# [573]	valid_0's auc: 0.824701	valid_0's binary_logloss: 0.338479
# [574]	valid_0's auc: 0.824703	valid_0's binary_logloss: 0.338478
# [575]	valid_0's auc: 0.824705	valid_0's binary_logloss: 0.338475
# [576]	valid_0's auc: 0.824707	valid_0's binary_logloss: 0.338474
# [577]	valid_0's auc: 0.82471	valid_0's binary_logloss: 0.338471
# [578]	valid_0's auc: 0.824715	valid_0's binary_logloss: 0.338465
# [579]	valid_0's auc: 0.824719	valid_0's binary_logloss: 0.338462
# [580]	valid_0's auc: 0.824743	valid_0's binary_logloss: 0.338442
# [581]	valid_0's auc: 0.824752	valid_0's binary_logloss: 0.338435
# [582]	valid_0's auc: 0.824759	valid_0's binary_logloss: 0.33843
# [583]	valid_0's auc: 0.824758	valid_0's binary_logloss: 0.33843
# [584]	valid_0's auc: 0.824759	valid_0's binary_logloss: 0.338429
# [585]	valid_0's auc: 0.824758	valid_0's binary_logloss: 0.33843
# [586]	valid_0's auc: 0.82476	valid_0's binary_logloss: 0.338429
# [587]	valid_0's auc: 0.824758	valid_0's binary_logloss: 0.33843
# [588]	valid_0's auc: 0.824755	valid_0's binary_logloss: 0.338432
# [589]	valid_0's auc: 0.824764	valid_0's binary_logloss: 0.338423
# [590]	valid_0's auc: 0.824769	valid_0's binary_logloss: 0.338417
# [591]	valid_0's auc: 0.824777	valid_0's binary_logloss: 0.338412
# [592]	valid_0's auc: 0.824782	valid_0's binary_logloss: 0.338407
# [593]	valid_0's auc: 0.824809	valid_0's binary_logloss: 0.338388
# [594]	valid_0's auc: 0.824814	valid_0's binary_logloss: 0.338383
# [595]	valid_0's auc: 0.824819	valid_0's binary_logloss: 0.33838
# [596]	valid_0's auc: 0.824845	valid_0's binary_logloss: 0.338359
# [597]	valid_0's auc: 0.824847	valid_0's binary_logloss: 0.338358
# [598]	valid_0's auc: 0.82485	valid_0's binary_logloss: 0.338354
# [599]	valid_0's auc: 0.824856	valid_0's binary_logloss: 0.338349
# [600]	valid_0's auc: 0.824858	valid_0's binary_logloss: 0.338347
# [601]	valid_0's auc: 0.824855	valid_0's binary_logloss: 0.338349
# [602]	valid_0's auc: 0.824858	valid_0's binary_logloss: 0.338346
# [603]	valid_0's auc: 0.82486	valid_0's binary_logloss: 0.338344
# [604]	valid_0's auc: 0.824862	valid_0's binary_logloss: 0.338343
# [605]	valid_0's auc: 0.824903	valid_0's binary_logloss: 0.338307
# [606]	valid_0's auc: 0.824911	valid_0's binary_logloss: 0.338301
# [607]	valid_0's auc: 0.824916	valid_0's binary_logloss: 0.338296
# [608]	valid_0's auc: 0.824922	valid_0's binary_logloss: 0.338291
# [609]	valid_0's auc: 0.82493	valid_0's binary_logloss: 0.338283
# [610]	valid_0's auc: 0.824934	valid_0's binary_logloss: 0.33828
# [611]	valid_0's auc: 0.824944	valid_0's binary_logloss: 0.338274
# [612]	valid_0's auc: 0.824946	valid_0's binary_logloss: 0.33827
# [613]	valid_0's auc: 0.824943	valid_0's binary_logloss: 0.338272
# [614]	valid_0's auc: 0.824942	valid_0's binary_logloss: 0.338271
# [615]	valid_0's auc: 0.824941	valid_0's binary_logloss: 0.33827
# [616]	valid_0's auc: 0.82495	valid_0's binary_logloss: 0.338263
# [617]	valid_0's auc: 0.824957	valid_0's binary_logloss: 0.338256
# [618]	valid_0's auc: 0.824965	valid_0's binary_logloss: 0.338251
# [619]	valid_0's auc: 0.824968	valid_0's binary_logloss: 0.338249
# [620]	valid_0's auc: 0.824974	valid_0's binary_logloss: 0.338244
# [621]	valid_0's auc: 0.824978	valid_0's binary_logloss: 0.338241
# [622]	valid_0's auc: 0.824987	valid_0's binary_logloss: 0.338235
# [623]	valid_0's auc: 0.824992	valid_0's binary_logloss: 0.338231
# [624]	valid_0's auc: 0.825002	valid_0's binary_logloss: 0.338223
# [625]	valid_0's auc: 0.825011	valid_0's binary_logloss: 0.338217
# [626]	valid_0's auc: 0.825018	valid_0's binary_logloss: 0.338212
# [627]	valid_0's auc: 0.825019	valid_0's binary_logloss: 0.338211
# [628]	valid_0's auc: 0.825023	valid_0's binary_logloss: 0.338209
# [629]	valid_0's auc: 0.825039	valid_0's binary_logloss: 0.338197
# [630]	valid_0's auc: 0.82505	valid_0's binary_logloss: 0.338188
# [631]	valid_0's auc: 0.825055	valid_0's binary_logloss: 0.338186
# [632]	valid_0's auc: 0.825059	valid_0's binary_logloss: 0.338182
# [633]	valid_0's auc: 0.825056	valid_0's binary_logloss: 0.338184
# [634]	valid_0's auc: 0.825061	valid_0's binary_logloss: 0.338182
# [635]	valid_0's auc: 0.825058	valid_0's binary_logloss: 0.338183
# [636]	valid_0's auc: 0.825057	valid_0's binary_logloss: 0.338184
# [637]	valid_0's auc: 0.825069	valid_0's binary_logloss: 0.338176
# [638]	valid_0's auc: 0.825075	valid_0's binary_logloss: 0.338171
# [639]	valid_0's auc: 0.825079	valid_0's binary_logloss: 0.338168
# [640]	valid_0's auc: 0.82508	valid_0's binary_logloss: 0.338169
# [641]	valid_0's auc: 0.825078	valid_0's binary_logloss: 0.33817
# [642]	valid_0's auc: 0.82508	valid_0's binary_logloss: 0.338168
# [643]	valid_0's auc: 0.825087	valid_0's binary_logloss: 0.338161
# [644]	valid_0's auc: 0.825091	valid_0's binary_logloss: 0.338158
# [645]	valid_0's auc: 0.8251	valid_0's binary_logloss: 0.33815
# [646]	valid_0's auc: 0.825108	valid_0's binary_logloss: 0.338144
# [647]	valid_0's auc: 0.825115	valid_0's binary_logloss: 0.338139
# [648]	valid_0's auc: 0.825118	valid_0's binary_logloss: 0.338136
# [649]	valid_0's auc: 0.825131	valid_0's binary_logloss: 0.338125
# [650]	valid_0's auc: 0.825132	valid_0's binary_logloss: 0.338124
# [651]	valid_0's auc: 0.82514	valid_0's binary_logloss: 0.338118
# [652]	valid_0's auc: 0.825145	valid_0's binary_logloss: 0.338114
# [653]	valid_0's auc: 0.825149	valid_0's binary_logloss: 0.33811
# [654]	valid_0's auc: 0.825154	valid_0's binary_logloss: 0.338105
# [655]	valid_0's auc: 0.825161	valid_0's binary_logloss: 0.338099
# [656]	valid_0's auc: 0.825164	valid_0's binary_logloss: 0.338098
# [657]	valid_0's auc: 0.825163	valid_0's binary_logloss: 0.338099
# [658]	valid_0's auc: 0.825167	valid_0's binary_logloss: 0.338095
# [659]	valid_0's auc: 0.82517	valid_0's binary_logloss: 0.338093
# [660]	valid_0's auc: 0.825177	valid_0's binary_logloss: 0.338088
# [661]	valid_0's auc: 0.825183	valid_0's binary_logloss: 0.338083
# [662]	valid_0's auc: 0.82519	valid_0's binary_logloss: 0.338079
# [663]	valid_0's auc: 0.825203	valid_0's binary_logloss: 0.33806
# [664]	valid_0's auc: 0.825209	valid_0's binary_logloss: 0.338056
# [665]	valid_0's auc: 0.825213	valid_0's binary_logloss: 0.338052
# [666]	valid_0's auc: 0.825245	valid_0's binary_logloss: 0.338031
# [667]	valid_0's auc: 0.825244	valid_0's binary_logloss: 0.338031
# [668]	valid_0's auc: 0.825249	valid_0's binary_logloss: 0.338026
# [669]	valid_0's auc: 0.825274	valid_0's binary_logloss: 0.338006
# [670]	valid_0's auc: 0.825278	valid_0's binary_logloss: 0.338002
# [671]	valid_0's auc: 0.825277	valid_0's binary_logloss: 0.338001
# [672]	valid_0's auc: 0.825285	valid_0's binary_logloss: 0.337995
# [673]	valid_0's auc: 0.825289	valid_0's binary_logloss: 0.337992
# [674]	valid_0's auc: 0.825294	valid_0's binary_logloss: 0.337989
# [675]	valid_0's auc: 0.825291	valid_0's binary_logloss: 0.33799
# [676]	valid_0's auc: 0.825295	valid_0's binary_logloss: 0.337987
# [677]	valid_0's auc: 0.825296	valid_0's binary_logloss: 0.337985
# [678]	valid_0's auc: 0.825296	valid_0's binary_logloss: 0.337985
# [679]	valid_0's auc: 0.825294	valid_0's binary_logloss: 0.337987
# [680]	valid_0's auc: 0.825297	valid_0's binary_logloss: 0.337984
# [681]	valid_0's auc: 0.825299	valid_0's binary_logloss: 0.337982
# [682]	valid_0's auc: 0.825298	valid_0's binary_logloss: 0.337983
# [683]	valid_0's auc: 0.825297	valid_0's binary_logloss: 0.337983
# [684]	valid_0's auc: 0.8253	valid_0's binary_logloss: 0.337981
# [685]	valid_0's auc: 0.825299	valid_0's binary_logloss: 0.337981
# [686]	valid_0's auc: 0.825304	valid_0's binary_logloss: 0.337977
# [687]	valid_0's auc: 0.825311	valid_0's binary_logloss: 0.337971
# [688]	valid_0's auc: 0.825318	valid_0's binary_logloss: 0.337967
# [689]	valid_0's auc: 0.825321	valid_0's binary_logloss: 0.337965
# [690]	valid_0's auc: 0.825319	valid_0's binary_logloss: 0.337967
# [691]	valid_0's auc: 0.825326	valid_0's binary_logloss: 0.337962
# [692]	valid_0's auc: 0.825336	valid_0's binary_logloss: 0.337953
# [693]	valid_0's auc: 0.825341	valid_0's binary_logloss: 0.337949
# [694]	valid_0's auc: 0.825343	valid_0's binary_logloss: 0.337948
# [695]	valid_0's auc: 0.825345	valid_0's binary_logloss: 0.337946
# [696]	valid_0's auc: 0.825349	valid_0's binary_logloss: 0.337941
# [697]	valid_0's auc: 0.82535	valid_0's binary_logloss: 0.337941
# [698]	valid_0's auc: 0.825349	valid_0's binary_logloss: 0.337942
# [699]	valid_0's auc: 0.825349	valid_0's binary_logloss: 0.337941
# [700]	valid_0's auc: 0.825351	valid_0's binary_logloss: 0.33794
# [701]	valid_0's auc: 0.825353	valid_0's binary_logloss: 0.337939
# [702]	valid_0's auc: 0.825356	valid_0's binary_logloss: 0.337937
# [703]	valid_0's auc: 0.82536	valid_0's binary_logloss: 0.337934
# [704]	valid_0's auc: 0.825366	valid_0's binary_logloss: 0.33793
# [705]	valid_0's auc: 0.825371	valid_0's binary_logloss: 0.337926
# [706]	valid_0's auc: 0.825367	valid_0's binary_logloss: 0.337927
# [707]	valid_0's auc: 0.82537	valid_0's binary_logloss: 0.337926
# [708]	valid_0's auc: 0.825375	valid_0's binary_logloss: 0.337922
# [709]	valid_0's auc: 0.825383	valid_0's binary_logloss: 0.337916
# [710]	valid_0's auc: 0.825391	valid_0's binary_logloss: 0.337911
# [711]	valid_0's auc: 0.825391	valid_0's binary_logloss: 0.337911
# [712]	valid_0's auc: 0.825391	valid_0's binary_logloss: 0.337911
# [713]	valid_0's auc: 0.825384	valid_0's binary_logloss: 0.337914
# [714]	valid_0's auc: 0.825384	valid_0's binary_logloss: 0.337913
# [715]	valid_0's auc: 0.825391	valid_0's binary_logloss: 0.337909
# [716]	valid_0's auc: 0.82539	valid_0's binary_logloss: 0.33791
# [717]	valid_0's auc: 0.825406	valid_0's binary_logloss: 0.337895
# [718]	valid_0's auc: 0.825414	valid_0's binary_logloss: 0.337889
# [719]	valid_0's auc: 0.825422	valid_0's binary_logloss: 0.337883
# [720]	valid_0's auc: 0.825427	valid_0's binary_logloss: 0.337879
# [721]	valid_0's auc: 0.825442	valid_0's binary_logloss: 0.337867
# [722]	valid_0's auc: 0.825447	valid_0's binary_logloss: 0.337862
# [723]	valid_0's auc: 0.825461	valid_0's binary_logloss: 0.337851
# [724]	valid_0's auc: 0.825468	valid_0's binary_logloss: 0.337847
# [725]	valid_0's auc: 0.825469	valid_0's binary_logloss: 0.337845
# [726]	valid_0's auc: 0.825473	valid_0's binary_logloss: 0.337842
# [727]	valid_0's auc: 0.825472	valid_0's binary_logloss: 0.337841
# [728]	valid_0's auc: 0.82548	valid_0's binary_logloss: 0.337836
# [729]	valid_0's auc: 0.825483	valid_0's binary_logloss: 0.337834
# [730]	valid_0's auc: 0.825495	valid_0's binary_logloss: 0.337825
# [731]	valid_0's auc: 0.825487	valid_0's binary_logloss: 0.337829
# [732]	valid_0's auc: 0.825486	valid_0's binary_logloss: 0.337829
# [733]	valid_0's auc: 0.825494	valid_0's binary_logloss: 0.337823
# [734]	valid_0's auc: 0.825503	valid_0's binary_logloss: 0.337812
# [735]	valid_0's auc: 0.825505	valid_0's binary_logloss: 0.337808
# [736]	valid_0's auc: 0.825508	valid_0's binary_logloss: 0.337806
# [737]	valid_0's auc: 0.825509	valid_0's binary_logloss: 0.337805
# [738]	valid_0's auc: 0.82552	valid_0's binary_logloss: 0.337796
# [739]	valid_0's auc: 0.825524	valid_0's binary_logloss: 0.337793
# ...
# [1767]	valid_0's auc: 0.829116	valid_0's binary_logloss: 0.334942
# [1768]	valid_0's auc: 0.829116	valid_0's binary_logloss: 0.334942
# [1769]	valid_0's auc: 0.829112	valid_0's binary_logloss: 0.334944
# [1770]	valid_0's auc: 0.829112	valid_0's binary_logloss: 0.334944
# [1771]	valid_0's auc: 0.82912	valid_0's binary_logloss: 0.334938
# [1772]	valid_0's auc: 0.829124	valid_0's binary_logloss: 0.334934
# [1773]	valid_0's auc: 0.829125	valid_0's binary_logloss: 0.334932
# [1774]	valid_0's auc: 0.829125	valid_0's binary_logloss: 0.334933
# [1775]	valid_0's auc: 0.829128	valid_0's binary_logloss: 0.334931
# [1776]	valid_0's auc: 0.829136	valid_0's binary_logloss: 0.334926
# [1777]	valid_0's auc: 0.829143	valid_0's binary_logloss: 0.33492
# [1778]	valid_0's auc: 0.829142	valid_0's binary_logloss: 0.334921
# [1779]	valid_0's auc: 0.829143	valid_0's binary_logloss: 0.33492
# [1780]	valid_0's auc: 0.829152	valid_0's binary_logloss: 0.334914
# [1781]	valid_0's auc: 0.829157	valid_0's binary_logloss: 0.334912
# [1782]	valid_0's auc: 0.829153	valid_0's binary_logloss: 0.334914
# [1783]	valid_0's auc: 0.829156	valid_0's binary_logloss: 0.334911
# [1784]	valid_0's auc: 0.829155	valid_0's binary_logloss: 0.334911
# [1785]	valid_0's auc: 0.829151	valid_0's binary_logloss: 0.334914
# [1786]	valid_0's auc: 0.829157	valid_0's binary_logloss: 0.33491
# [1787]	valid_0's auc: 0.829159	valid_0's binary_logloss: 0.334907
# [1788]	valid_0's auc: 0.829163	valid_0's binary_logloss: 0.334904
# [1789]	valid_0's auc: 0.829158	valid_0's binary_logloss: 0.334906
# [1790]	valid_0's auc: 0.829158	valid_0's binary_logloss: 0.334907
# [1791]	valid_0's auc: 0.829165	valid_0's binary_logloss: 0.334901
# [1792]	valid_0's auc: 0.829164	valid_0's binary_logloss: 0.334901
# [1793]	valid_0's auc: 0.829169	valid_0's binary_logloss: 0.334898
# [1794]	valid_0's auc: 0.82917	valid_0's binary_logloss: 0.334896
# [1795]	valid_0's auc: 0.829172	valid_0's binary_logloss: 0.334894
# [1796]	valid_0's auc: 0.829173	valid_0's binary_logloss: 0.334893
# [1797]	valid_0's auc: 0.829175	valid_0's binary_logloss: 0.334891
# [1798]	valid_0's auc: 0.829175	valid_0's binary_logloss: 0.334892
# [1799]	valid_0's auc: 0.829175	valid_0's binary_logloss: 0.334892
# [1800]	valid_0's auc: 0.829172	valid_0's binary_logloss: 0.334894
# [1801]	valid_0's auc: 0.829176	valid_0's binary_logloss: 0.334891
# [1802]	valid_0's auc: 0.829177	valid_0's binary_logloss: 0.334889
# [1803]	valid_0's auc: 0.829184	valid_0's binary_logloss: 0.334882
# [1804]	valid_0's auc: 0.829193	valid_0's binary_logloss: 0.334874
# [1805]	valid_0's auc: 0.829196	valid_0's binary_logloss: 0.334873
# [1806]	valid_0's auc: 0.829201	valid_0's binary_logloss: 0.334869
# [1807]	valid_0's auc: 0.829204	valid_0's binary_logloss: 0.334867
# [1808]	valid_0's auc: 0.829204	valid_0's binary_logloss: 0.334867
# [1809]	valid_0's auc: 0.829206	valid_0's binary_logloss: 0.334865
# [1810]	valid_0's auc: 0.829205	valid_0's binary_logloss: 0.334866
# [1811]	valid_0's auc: 0.829211	valid_0's binary_logloss: 0.334862
# [1812]	valid_0's auc: 0.829209	valid_0's binary_logloss: 0.334862
# [1813]	valid_0's auc: 0.829206	valid_0's binary_logloss: 0.334865
# [1814]	valid_0's auc: 0.829201	valid_0's binary_logloss: 0.33487
# [1815]	valid_0's auc: 0.829208	valid_0's binary_logloss: 0.334865
# [1816]	valid_0's auc: 0.829209	valid_0's binary_logloss: 0.334864
# [1817]	valid_0's auc: 0.829207	valid_0's binary_logloss: 0.334865
# [1818]	valid_0's auc: 0.829208	valid_0's binary_logloss: 0.334865
# [1819]	valid_0's auc: 0.829213	valid_0's binary_logloss: 0.334862
# [1820]	valid_0's auc: 0.829211	valid_0's binary_logloss: 0.334863
# [1821]	valid_0's auc: 0.829211	valid_0's binary_logloss: 0.334864
# [1822]	valid_0's auc: 0.82921	valid_0's binary_logloss: 0.334864
# [1823]	valid_0's auc: 0.829216	valid_0's binary_logloss: 0.334861
# [1824]	valid_0's auc: 0.829213	valid_0's binary_logloss: 0.334862
# [1825]	valid_0's auc: 0.829214	valid_0's binary_logloss: 0.33486
# [1826]	valid_0's auc: 0.829214	valid_0's binary_logloss: 0.334861
# [1827]	valid_0's auc: 0.829215	valid_0's binary_logloss: 0.334859
# [1828]	valid_0's auc: 0.829213	valid_0's binary_logloss: 0.33486
# [1829]	valid_0's auc: 0.82922	valid_0's binary_logloss: 0.334855
# [1830]	valid_0's auc: 0.829223	valid_0's binary_logloss: 0.334852
# [1831]	valid_0's auc: 0.829224	valid_0's binary_logloss: 0.334851
# [1832]	valid_0's auc: 0.829223	valid_0's binary_logloss: 0.334851
# [1833]	valid_0's auc: 0.829221	valid_0's binary_logloss: 0.334853
# [1834]	valid_0's auc: 0.829223	valid_0's binary_logloss: 0.33485
# [1835]	valid_0's auc: 0.829225	valid_0's binary_logloss: 0.334849
# [1836]	valid_0's auc: 0.829222	valid_0's binary_logloss: 0.334851
# [1837]	valid_0's auc: 0.829223	valid_0's binary_logloss: 0.334851
# [1838]	valid_0's auc: 0.82923	valid_0's binary_logloss: 0.334846
# [1839]	valid_0's auc: 0.829231	valid_0's binary_logloss: 0.334844
# [1840]	valid_0's auc: 0.829234	valid_0's binary_logloss: 0.334842
# [1841]	valid_0's auc: 0.829237	valid_0's binary_logloss: 0.334841
# [1842]	valid_0's auc: 0.829239	valid_0's binary_logloss: 0.33484
# [1843]	valid_0's auc: 0.829241	valid_0's binary_logloss: 0.334839
# [1844]	valid_0's auc: 0.829247	valid_0's binary_logloss: 0.334835
# [1845]	valid_0's auc: 0.829248	valid_0's binary_logloss: 0.334834
# [1846]	valid_0's auc: 0.829248	valid_0's binary_logloss: 0.334835
# [1847]	valid_0's auc: 0.829252	valid_0's binary_logloss: 0.334832
# [1848]	valid_0's auc: 0.829255	valid_0's binary_logloss: 0.334829
# [1849]	valid_0's auc: 0.829257	valid_0's binary_logloss: 0.334829
# [1850]	valid_0's auc: 0.829263	valid_0's binary_logloss: 0.334825
# [1851]	valid_0's auc: 0.829264	valid_0's binary_logloss: 0.334824
# [1852]	valid_0's auc: 0.829262	valid_0's binary_logloss: 0.334825
# [1853]	valid_0's auc: 0.829263	valid_0's binary_logloss: 0.334825
# [1854]	valid_0's auc: 0.829264	valid_0's binary_logloss: 0.334824
# [1855]	valid_0's auc: 0.829265	valid_0's binary_logloss: 0.334824
# [1856]	valid_0's auc: 0.829263	valid_0's binary_logloss: 0.334826
# [1857]	valid_0's auc: 0.829263	valid_0's binary_logloss: 0.334827
# [1858]	valid_0's auc: 0.82926	valid_0's binary_logloss: 0.334829
# [1859]	valid_0's auc: 0.829262	valid_0's binary_logloss: 0.334828
# [1860]	valid_0's auc: 0.829267	valid_0's binary_logloss: 0.334823
# [1861]	valid_0's auc: 0.829269	valid_0's binary_logloss: 0.334823
# [1862]	valid_0's auc: 0.829275	valid_0's binary_logloss: 0.33482
# [1863]	valid_0's auc: 0.829277	valid_0's binary_logloss: 0.334818
# [1864]	valid_0's auc: 0.829286	valid_0's binary_logloss: 0.334811
# [1865]	valid_0's auc: 0.829289	valid_0's binary_logloss: 0.334808
# [1866]	valid_0's auc: 0.829289	valid_0's binary_logloss: 0.334808
# [1867]	valid_0's auc: 0.829292	valid_0's binary_logloss: 0.334805
# [1868]	valid_0's auc: 0.829306	valid_0's binary_logloss: 0.334796
# [1869]	valid_0's auc: 0.829305	valid_0's binary_logloss: 0.334796
# [1870]	valid_0's auc: 0.829307	valid_0's binary_logloss: 0.334795
# [1871]	valid_0's auc: 0.82931	valid_0's binary_logloss: 0.334792
# [1872]	valid_0's auc: 0.82931	valid_0's binary_logloss: 0.334792
# [1873]	valid_0's auc: 0.82931	valid_0's binary_logloss: 0.334791
# [1874]	valid_0's auc: 0.82931	valid_0's binary_logloss: 0.334791
# [1875]	valid_0's auc: 0.829311	valid_0's binary_logloss: 0.334792
# [1876]	valid_0's auc: 0.829313	valid_0's binary_logloss: 0.334791
# [1877]	valid_0's auc: 0.829316	valid_0's binary_logloss: 0.334788
# [1878]	valid_0's auc: 0.829314	valid_0's binary_logloss: 0.334789
# [1879]	valid_0's auc: 0.829313	valid_0's binary_logloss: 0.33479
# [1880]	valid_0's auc: 0.829312	valid_0's binary_logloss: 0.33479
# [1881]	valid_0's auc: 0.829311	valid_0's binary_logloss: 0.334791
# [1882]	valid_0's auc: 0.829311	valid_0's binary_logloss: 0.334791
# [1883]	valid_0's auc: 0.82931	valid_0's binary_logloss: 0.334791
# [1884]	valid_0's auc: 0.829311	valid_0's binary_logloss: 0.334791
# [1885]	valid_0's auc: 0.829309	valid_0's binary_logloss: 0.334792
# [1886]	valid_0's auc: 0.829303	valid_0's binary_logloss: 0.334795
# [1887]	valid_0's auc: 0.829304	valid_0's binary_logloss: 0.334794
# [1888]	valid_0's auc: 0.829302	valid_0's binary_logloss: 0.334796
# [1889]	valid_0's auc: 0.829301	valid_0's binary_logloss: 0.334796
# [1890]	valid_0's auc: 0.829302	valid_0's binary_logloss: 0.334796
# [1891]	valid_0's auc: 0.829308	valid_0's binary_logloss: 0.334791
# [1892]	valid_0's auc: 0.82931	valid_0's binary_logloss: 0.33479
# [1893]	valid_0's auc: 0.82931	valid_0's binary_logloss: 0.33479
# [1894]	valid_0's auc: 0.82931	valid_0's binary_logloss: 0.33479
# [1895]	valid_0's auc: 0.829311	valid_0's binary_logloss: 0.334789
# [1896]	valid_0's auc: 0.829309	valid_0's binary_logloss: 0.33479
# [1897]	valid_0's auc: 0.829308	valid_0's binary_logloss: 0.334791
# [1898]	valid_0's auc: 0.829306	valid_0's binary_logloss: 0.334792
# [1899]	valid_0's auc: 0.829305	valid_0's binary_logloss: 0.334793
# [1900]	valid_0's auc: 0.829306	valid_0's binary_logloss: 0.334793
# [1901]	valid_0's auc: 0.829305	valid_0's binary_logloss: 0.334795
# [1902]	valid_0's auc: 0.829303	valid_0's binary_logloss: 0.334794
# [1903]	valid_0's auc: 0.829303	valid_0's binary_logloss: 0.334794
# [1904]	valid_0's auc: 0.829307	valid_0's binary_logloss: 0.334792
# [1905]	valid_0's auc: 0.829312	valid_0's binary_logloss: 0.334788
# [1906]	valid_0's auc: 0.829314	valid_0's binary_logloss: 0.334787
# [1907]	valid_0's auc: 0.829316	valid_0's binary_logloss: 0.334785
# [1908]	valid_0's auc: 0.829321	valid_0's binary_logloss: 0.334782
# [1909]	valid_0's auc: 0.82932	valid_0's binary_logloss: 0.334783
# [1910]	valid_0's auc: 0.829321	valid_0's binary_logloss: 0.334781
# [1911]	valid_0's auc: 0.829322	valid_0's binary_logloss: 0.334781
# [1912]	valid_0's auc: 0.829322	valid_0's binary_logloss: 0.33478
# [1913]	valid_0's auc: 0.829319	valid_0's binary_logloss: 0.334782
# [1914]	valid_0's auc: 0.829331	valid_0's binary_logloss: 0.334772
# [1915]	valid_0's auc: 0.829343	valid_0's binary_logloss: 0.334765
# [1916]	valid_0's auc: 0.829348	valid_0's binary_logloss: 0.334761
# [1917]	valid_0's auc: 0.829353	valid_0's binary_logloss: 0.334757
# [1918]	valid_0's auc: 0.829351	valid_0's binary_logloss: 0.334758
# [1919]	valid_0's auc: 0.829348	valid_0's binary_logloss: 0.33476
# [1920]	valid_0's auc: 0.829348	valid_0's binary_logloss: 0.33476
# [1921]	valid_0's auc: 0.829348	valid_0's binary_logloss: 0.33476
# [1922]	valid_0's auc: 0.829348	valid_0's binary_logloss: 0.334759
# [1923]	valid_0's auc: 0.829349	valid_0's binary_logloss: 0.334758
# [1924]	valid_0's auc: 0.82935	valid_0's binary_logloss: 0.334757
# [1925]	valid_0's auc: 0.829349	valid_0's binary_logloss: 0.334757
# [1926]	valid_0's auc: 0.829351	valid_0's binary_logloss: 0.334756
# [1927]	valid_0's auc: 0.829354	valid_0's binary_logloss: 0.334754
# [1928]	valid_0's auc: 0.829355	valid_0's binary_logloss: 0.334753
# [1929]	valid_0's auc: 0.829356	valid_0's binary_logloss: 0.334752
# [1930]	valid_0's auc: 0.829358	valid_0's binary_logloss: 0.33475
# [1931]	valid_0's auc: 0.829364	valid_0's binary_logloss: 0.334744
# [1932]	valid_0's auc: 0.829364	valid_0's binary_logloss: 0.334743
# [1933]	valid_0's auc: 0.829362	valid_0's binary_logloss: 0.334745
# [1934]	valid_0's auc: 0.829359	valid_0's binary_logloss: 0.334747
# [1935]	valid_0's auc: 0.829358	valid_0's binary_logloss: 0.334747
# [1936]	valid_0's auc: 0.829355	valid_0's binary_logloss: 0.33475
# [1937]	valid_0's auc: 0.829357	valid_0's binary_logloss: 0.334748
# [1938]	valid_0's auc: 0.829355	valid_0's binary_logloss: 0.334749
# [1939]	valid_0's auc: 0.829358	valid_0's binary_logloss: 0.334747
# [1940]	valid_0's auc: 0.829363	valid_0's binary_logloss: 0.334744
# [1941]	valid_0's auc: 0.829362	valid_0's binary_logloss: 0.334745
# [1942]	valid_0's auc: 0.829359	valid_0's binary_logloss: 0.334747
# [1943]	valid_0's auc: 0.82936	valid_0's binary_logloss: 0.334746
# [1944]	valid_0's auc: 0.829358	valid_0's binary_logloss: 0.334747
# [1945]	valid_0's auc: 0.829357	valid_0's binary_logloss: 0.334748
# [1946]	valid_0's auc: 0.829354	valid_0's binary_logloss: 0.334751
# [1947]	valid_0's auc: 0.829354	valid_0's binary_logloss: 0.334751
# [1948]	valid_0's auc: 0.829351	valid_0's binary_logloss: 0.334753
# [1949]	valid_0's auc: 0.829351	valid_0's binary_logloss: 0.334752
# [1950]	valid_0's auc: 0.829351	valid_0's binary_logloss: 0.334752
# [1951]	valid_0's auc: 0.829358	valid_0's binary_logloss: 0.334748
# [1952]	valid_0's auc: 0.829361	valid_0's binary_logloss: 0.334746
# [1953]	valid_0's auc: 0.829359	valid_0's binary_logloss: 0.334748
# [1954]	valid_0's auc: 0.82936	valid_0's binary_logloss: 0.334748
# [1955]	valid_0's auc: 0.829357	valid_0's binary_logloss: 0.33475
# [1956]	valid_0's auc: 0.829362	valid_0's binary_logloss: 0.334747
# [1957]	valid_0's auc: 0.829364	valid_0's binary_logloss: 0.334745
# [1958]	valid_0's auc: 0.829364	valid_0's binary_logloss: 0.334745
# [1959]	valid_0's auc: 0.829362	valid_0's binary_logloss: 0.334746
# [1960]	valid_0's auc: 0.829363	valid_0's binary_logloss: 0.334746
# [1961]	valid_0's auc: 0.829365	valid_0's binary_logloss: 0.334744
# [1962]	valid_0's auc: 0.829368	valid_0's binary_logloss: 0.334742
# [1963]	valid_0's auc: 0.82937	valid_0's binary_logloss: 0.334742
# [1964]	valid_0's auc: 0.829369	valid_0's binary_logloss: 0.334743
# [1965]	valid_0's auc: 0.829372	valid_0's binary_logloss: 0.33474
# [1966]	valid_0's auc: 0.829371	valid_0's binary_logloss: 0.334741
# [1967]	valid_0's auc: 0.829371	valid_0's binary_logloss: 0.33474
# [1968]	valid_0's auc: 0.829371	valid_0's binary_logloss: 0.33474
# [1969]	valid_0's auc: 0.829368	valid_0's binary_logloss: 0.334742
# [1970]	valid_0's auc: 0.82937	valid_0's binary_logloss: 0.334741
# [1971]	valid_0's auc: 0.829369	valid_0's binary_logloss: 0.334742
# [1972]	valid_0's auc: 0.82937	valid_0's binary_logloss: 0.334741
# [1973]	valid_0's auc: 0.829371	valid_0's binary_logloss: 0.33474
# [1974]	valid_0's auc: 0.829368	valid_0's binary_logloss: 0.334742
# [1975]	valid_0's auc: 0.829374	valid_0's binary_logloss: 0.334737
# [1976]	valid_0's auc: 0.829372	valid_0's binary_logloss: 0.334738
# [1977]	valid_0's auc: 0.829378	valid_0's binary_logloss: 0.334734
# [1978]	valid_0's auc: 0.829377	valid_0's binary_logloss: 0.334734
# [1979]	valid_0's auc: 0.829383	valid_0's binary_logloss: 0.334731
# [1980]	valid_0's auc: 0.82938	valid_0's binary_logloss: 0.334733
# [1981]	valid_0's auc: 0.82938	valid_0's binary_logloss: 0.334733
# [1982]	valid_0's auc: 0.829383	valid_0's binary_logloss: 0.334729
# [1983]	valid_0's auc: 0.829381	valid_0's binary_logloss: 0.33473
# [1984]	valid_0's auc: 0.829385	valid_0's binary_logloss: 0.334726
# [1985]	valid_0's auc: 0.829383	valid_0's binary_logloss: 0.334728
# [1986]	valid_0's auc: 0.829385	valid_0's binary_logloss: 0.334726
# [1987]	valid_0's auc: 0.829387	valid_0's binary_logloss: 0.334725
# [1988]	valid_0's auc: 0.829387	valid_0's binary_logloss: 0.334725
# [1989]	valid_0's auc: 0.829385	valid_0's binary_logloss: 0.334726
# [1990]	valid_0's auc: 0.829387	valid_0's binary_logloss: 0.334724
# [1991]	valid_0's auc: 0.829388	valid_0's binary_logloss: 0.334724
# [1992]	valid_0's auc: 0.82939	valid_0's binary_logloss: 0.334722
# [1993]	valid_0's auc: 0.829387	valid_0's binary_logloss: 0.334724
# [1994]	valid_0's auc: 0.829385	valid_0's binary_logloss: 0.334724
# [1995]	valid_0's auc: 0.829388	valid_0's binary_logloss: 0.334723
# [1996]	valid_0's auc: 0.829387	valid_0's binary_logloss: 0.334723
# [1997]	valid_0's auc: 0.829383	valid_0's binary_logloss: 0.334725
# [1998]	valid_0's auc: 0.829383	valid_0's binary_logloss: 0.334726
# [1999]	valid_0's auc: 0.829383	valid_0's binary_logloss: 0.334726
# [2000]	valid_0's auc: 0.829382	valid_0's binary_logloss: 0.334726
# Did not meet early stopping. Best iteration is:
# [1992]	valid_0's auc: 0.82939	valid_0's binary_logloss: 0.334722
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=2000, n_jobs=-1, num_leaves=31, objective='binary',
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, seed=1000,
#         silent=True, subsample=1.0, subsample_for_bin=200000,
#         subsample_freq=0)

# %% [markdown]
# # 4 计算结果

# %%
sub['label'] = model_lgb.predict_proba(test[feature_cols])[:, 1]

# %%
sub.to_csv('./storage/result.txt', index=None, header=None, sep='\t')
